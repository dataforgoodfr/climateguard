# %%
import re
from asyncio import Semaphore
from typing import Literal

import fuzzysearch
import pandas as pd
from litellm import acompletion
from openpyxl import Workbook
from openpyxl.cell.rich_text import CellRichText, TextBlock
from openpyxl.cell.text import InlineFont
from openpyxl.styles import Alignment
from openpyxl.utils import get_column_letter
from openpyxl.worksheet.worksheet import Worksheet
from tqdm.asyncio import tqdm
from unidecode import unidecode

tqdm.pandas()

# %% [markdown]
# ## Preprocess and filter the claims extracted during the ECF Hackaton

# %%
df = pd.read_parquet("../../data/raw/4_channels_predictions_09_2023_09_2024.parquet")
df
# Out:
#                                                                  start  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be... 2023-09-01 06:26:00
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9... 2023-09-01 06:50:00
# b6d54aefb250671e7754a688411ce9e68badcad88a665be... 2023-09-01 07:38:00
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665... 2023-09-01 08:44:00
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412... 2023-09-01 08:46:00
# ...                                                                ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b... 2024-08-31 13:08:00
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858... 2024-08-31 13:10:00
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef... 2024-08-31 19:58:00
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249... 2024-08-31 20:18:00
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8... 2024-08-31 20:34:00
#
#                                                                                                  text  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  <unk> <unk> <unk> <unk> aerosmith en janvier m...
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  la très grande majorité d'entre eux ne connais...
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...  mais titeuf ne vieillit pas le monde change ti...
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  dû travailler très vite le journal arrive à no...
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  pas avoir lieu ni même européens existait ni l...
# ...                                                                                               ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...  lui aussi par les moustiques touche une trenta...
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...  des griffes arracher la solution se trouve peu...
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...  albret <unk> madame monsieur bonsoir bienvenue...
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  modèles rechargeables séduisent les citadins i...
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  viticoles françaises la saison des vendanges a...
#
#                                                    channel_name  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...      europe1
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...      europe1
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...      europe1
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...      europe1
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...      europe1
# ...                                                         ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...          tf1
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...          tf1
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...          tf1
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...          tf1
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...          tf1
#
#                                                     channel_is_radio  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...              True
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...              True
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...              True
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...              True
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...              True
# ...                                                              ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...             False
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...             False
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...             False
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...             False
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...             False
#
#                                                       channel_program_type  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  Information - Magazine
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  Information - Magazine
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...  Information - Magazine
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  Information - Magazine
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  Information - Magazine
# ...                                                                    ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...   Information - Journal
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...   Information - Journal
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...   Information - Journal
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...   Information - Journal
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...   Information - Journal
#
#                                                    channel_program  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...         Bonjour
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...         Bonjour
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...  Europe 1 Matin
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  Europe 1 Matin
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  Europe 1 Matin
# ...                                                            ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...          JT 13h
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...          JT 13h
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...  JT 20h + météo
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  JT 20h + météo
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  JT 20h + météo
#
#                                                                                                themes  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  ["biodiversite_concepts_generaux", "adaptation...
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  ["biodiversite_concepts_generaux", "changement...
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...                  ["changement_climatique_constat"]
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  ["biodiversite_concepts_generaux", "ressources...
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  ["biodiversite_concepts_generaux", "changement...
# ...                                                                                               ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...  ["biodiversite_consequences", "biodiversite_co...
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...  ["biodiversite_consequences", "attenuation_cli...
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...             ["changement_climatique_consequences"]
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  ["attenuation_climatique_solutions", "changeme...
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  ["attenuation_climatique_solutions", "changeme...
#
#                                                                                              keywords  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  [{"keyword": "eaux", "timestamp": 169354246806...
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  [{"keyword": "eaux", "timestamp": 169354380309...
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...  [{"keyword": "bilan carbone", "timestamp": 169...
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  [{"keyword": "eaux", "timestamp": 169355074908...
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  [{"keyword": "\u00e9cologiste", "timestamp": 1...
# ...                                                                                               ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...  [{"keyword": "renaturer", "timestamp": 1725102...
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...  [{"keyword": "agriculture", "timestamp": 17251...
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...  [{"keyword": "al\u00e9as climatiques", "timest...
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  [{"keyword": "borne de recharge", "timestamp":...
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  [{"keyword": "for\u00eat", "timestamp": 172512...
#
#                                                     num_keywords  num_tokens  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...             1         383
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...             3         593
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...             1         606
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...             3         515
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...             2         536
# ...                                                          ...         ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...             4         474
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...             3         471
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...             1         419
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...             2         503
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...             3         391
#
#                                                                                                claims
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  [{'analysis': 'Cette allégation nécessite une ...
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  [{'analysis': 'L'allégation semble être fondée...
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...  [{'analysis': 'Il est pertinent de vérifier si...
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  [{'analysis': 'Cette allégation est problémati...
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  [{'analysis': 'L'allégation concernant la chut...
# ...                                                                                               ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...  [{'analysis': 'Cette allégation est fondée sur...
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...  [{'analysis': 'L'allégation qu'une plante a de...
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...  [{'analysis': 'L'allégation sur la qualité de ...
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  [{'analysis': 'Cette allégation évoque un poin...
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  [{'analysis': 'L'allégation semble fondée car ...
#
# [39131 rows x 11 columns]

# %%
# Keep only the "high-level" claims
df["claims"] = df["claims"].apply(
    lambda claims: [
        claim for claim in claims if claim["disinformation_score"] == "high"
    ]
)
df = df[df["claims"].str.len() > 0].copy()
len(df)
# Out:
# 1494

# %%
# Less than 10% of claims have more than one claim per extract, let's keep just one for simplicity
# We keep the first one when there are several claims
display(df["claims"].str.len().quantile([0.9, 0.95, 0.99, 1]))
df["claims"] = df["claims"].str[0]
# Out:
# 0.90    1.0
# 0.95    2.0
# 0.99    2.0
# 1.00    3.0
# Name: claims, dtype: float64

# %%
# Now that we have one claim per extract we can flatten the list of claims into columns
claims = pd.json_normalize(df["claims"])
claims.index = df.index
df = pd.concat([df, claims], axis=1).drop(columns="claims")
df
# Out:
#                                                                  start  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7... 2023-09-04 05:56:00
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f... 2023-09-04 07:50:00
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd... 2023-09-06 07:22:00
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8... 2023-09-06 08:38:00
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca... 2023-09-07 08:56:00
# ...                                                                ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba... 2024-08-06 09:04:00
# deced996c604c36119a2b873d7ce1b0db917c2078711864... 2024-08-15 08:36:00
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf... 2024-08-17 20:24:00
# e641edd619674384dd37c0f35d0dff55354a299f76e564c... 2024-08-26 13:32:00
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955... 2024-08-28 07:18:00
#
#                                                                                                  text  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  série qu'on peut redire par fonction juré déjà...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  salle d'attente il y a toutes les classes rage...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  en france on peut quand même s'appuyer sur ce ...
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  je suis même allé plus loin je vais essayer de...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  pour faire réussir nos enfants dans quel monde...
# ...                                                                                               ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  chute de séracs sont communs commune à toutes ...
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  voyageurs à reporter leurs déplacements et à n...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  le vaucluse ses problèmes d'étiquetage représe...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  de foot passant déclinent c'est un signe qui a...
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  de baisser les montants de deux des frais dans...
#
#                                                    channel_name  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...      europe1
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...      europe1
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...      europe1
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...      europe1
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...      europe1
# ...                                                         ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...          tf1
# deced996c604c36119a2b873d7ce1b0db917c2078711864...          tf1
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...          tf1
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...          tf1
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...          tf1
#
#                                                     channel_is_radio  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...              True
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...              True
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...              True
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...              True
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...              True
# ...                                                              ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...             False
# deced996c604c36119a2b873d7ce1b0db917c2078711864...             False
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...             False
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...             False
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...             False
#
#                                                       channel_program_type  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  Information - Magazine
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  Information - Magazine
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  Information - Magazine
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  Information - Magazine
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  Information - Magazine
# ...                                                                    ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  Information - Magazine
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  Information - Magazine
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...   Information - Journal
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...   Information - Journal
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  Information - Magazine
#
#                                                           channel_program  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...                Bonjour
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...         Europe 1 Matin
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...         Europe 1 Matin
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...         Europe 1 Matin
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...       L'heure des pros
# ...                                                                   ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  Bonjour ! La Matinale
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  Bonjour ! La Matinale
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...         JT 20h + météo
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...                 JT 13h
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  Bonjour ! La Matinale
#
#                                                                                                themes  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  ["biodiversite_concepts_generaux", "changement...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  ["changement_climatique_causes", "changement_c...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  ["changement_climatique_consequences_indirecte...
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  ["changement_climatique_consequences", "ressou...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...                  ["changement_climatique_constat"]
# ...                                                                                               ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  ["changement_climatique_constat_indirectes", "...
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  ["changement_climatique_constat", "ressources_...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  ["biodiversite_concepts_generaux", "biodiversi...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  ["changement_climatique_causes_indirectes", "b...
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  ["changement_climatique_causes_indirectes", "b...
#
#                                                                                              keywords  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  [{"keyword": "eaux", "timestamp": 169379984302...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  [{"keyword": "giec", "timestamp": 169380664205...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  [{"keyword": "incendies", "timestamp": 1693977...
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  [{"keyword": "\u00e9coresponsable", "timestamp...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  [{"keyword": "climatique", "timestamp": 169406...
# ...                                                                                               ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  [{"keyword": "climatique", "timestamp": 172292...
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  [{"keyword": "incendies", "timestamp": 1723703...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  [{"keyword": "agriculteur", "timestamp": 17239...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  [{"keyword": "pollution", "timestamp": 1724671...
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  [{"keyword": "agricole", "timestamp": 17248223...
#
#                                                     num_keywords  num_tokens  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...             2         559
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...             2         554
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...             2         594
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...             2         614
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...             1         563
# ...                                                          ...         ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...             1         400
# deced996c604c36119a2b873d7ce1b0db917c2078711864...             3         515
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...             1         494
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...             2         387
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...             2         505
#
#                                                                                              analysis  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  Cette allégation semble associée à une interpr...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  Cette allégation semble utiliser le terme 'tra...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  Cette allégation semble hautement exagérée et ...
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  Cette allégation frôle la théorie du complot, ...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  Si le changement climatique est parfois utilis...
# ...                                                                                               ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  Cette affirmation semble contestable, car de n...
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  Cette allégation est assez sérieuse, car elle ...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  Cette information est manifestement fausse et ...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  Cette allégation sur la modification génétique...
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  Cette déclaration semble exagérée et doit être...
#
#                                                                                                 claim  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...                         le giec est transhumaniste
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...      La mention du GIEC comme un "transhumaniste".
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  Il y a eu beaucoup de morts tués par des pharm...
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  Le réchauffement climatique est causé par une ...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  Le changement climatique est traité comme une ...
# ...                                                                                               ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  Le risque de chutes de séracs n'est pas partic...
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  les forêts ont absorbé deux fois moins de CO2 ...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  Une astuce sur les réseaux sociaux prétend que...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  Il y a une modification génétique chez les hér...
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  La surface agricole consacrée à la moutarde es...
#
#                                                                                               context  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  Dans un passage en parlant des personnages du ...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  Dans un extrait de programme où différents per...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  Lors d'une discussion sur le rôle des pharmaci...
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  Lors d'une discussion sur les enjeux environne...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  Le commentaire sur une polémique entre personn...
# ...                                                                                               ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  Le chercheur indique que, pour l'instant, le r...
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  Le commentateur souligne une diminution de l'a...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  Un segment aborde une nouvelle tendance sur le...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  L'intervenant suggère que la population de hér...
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  Il a été mentionné que la surface agricole déd...
#
#                                                    contradiction  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...           N/A
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...           N/A
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...           N/A
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...           N/A
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...           N/A
# ...                                                          ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...           N/A
# deced996c604c36119a2b873d7ce1b0db917c2078711864...           N/A
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...           N/A
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...           N/A
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...           N/A
#
#                                                    disinformation_category  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...               consensus
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...               consensus
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...               narrative
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...               consensus
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...               consensus
# ...                                                                    ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...               consensus
# deced996c604c36119a2b873d7ce1b0db917c2078711864...               consensus
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...               narrative
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...               consensus
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...                   facts
#
#                                                    disinformation_score  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...                 high
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...                 high
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...                 high
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...                 high
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...                 high
# ...                                                                 ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...                 high
# deced996c604c36119a2b873d7ce1b0db917c2078711864...                 high
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...                 high
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...                 high
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...                 high
#
#                                                          pro_anti  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  anti-écologie
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  anti-écologie
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  anti-écologie
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  anti-écologie
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  anti-écologie
# ...                                                           ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  anti-écologie
# deced996c604c36119a2b873d7ce1b0db917c2078711864...   pro-écologie
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  anti-écologie
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  anti-écologie
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...   pro-écologie
#
#                                                                                                 quote  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  il y a par exemple le giec transhumaniste qui ...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  il y a par exemple le giec transhumaniste qui ...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  j'ai l'impression qu'il y a eu beaucoup de mor...
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  Le réchauffement climatique est causé par une ...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  ...c'était hier soir dans cette à vous sur fra...
# ...                                                                                               ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  Pour l'instant, le risque de chutes de séracs ...
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  les forêts ont absorbé deux fois moins de CO2 ...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...    Cette astuce elle est fausse et voilà pourquoi.
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  en théorie ça doit être parce qu'il y a une mo...
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  la surface agricole est passée de quatre mille...
#
#                                                       speaker
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  narrative
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  narrative
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  narrative
# 53b6b045672a2327c58c72a38a3ddb603587ad43421f8c8...  narrative
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  narrative
# ...                                                       ...
# 9441e27a4c144b4ceef27cb8bd44ae5b7ae0fd545fde2ba...  narrative
# deced996c604c36119a2b873d7ce1b0db917c2078711864...  consensus
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  narrative
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  consensus
# 8c2e543e8306309d572328a75d8682f3167aab0d2dcd955...  consensus
#
# [1494 rows x 19 columns]

# %%
# Keeping only the "anti-écologie" claims
display(df["pro_anti"].value_counts())
df = df[df["pro_anti"] == "anti-écologie"].copy()
len(df)
# Out:
# pro_anti
# anti-écologie    1377
# pro-écologie      117
# Name: count, dtype: int64
# 1377

# %%
# Try to retrieve the start & end indices of the identified quotes for each claim
# Since the LLM doesn't like typos and so on, it will rarely perfectly quote the original text
# Therefore we need to do approximate matching
# This matching code can be improved, it's still a bit wobbly


def approximate_match(text: str, quote: str) -> tuple[int, int] | None:
    # Preprocess text to remove casing and accents
    text = unidecode(text.lower())
    quote = unidecode(quote.lower())

    match = fuzzysearch.find_near_matches(
        quote, text, max_l_dist=min(int(0.2 * len(quote)), 20)
    )

    if match:
        return match[0].start, match[0].end


# If we can't retrieve the quote from the original text, we simply ditch this identified claim for now
df["match"] = df.progress_apply(
    lambda x: approximate_match(x["text"], x["quote"]), axis=1
)
display((~df["match"].isna()).value_counts())

df = df[~df["match"].isna()].copy()

df["quote_start"] = df["match"].str[0]
df["quote_end"] = df["match"].str[1]
df = df.drop(columns="match")
len(df)
# Out:
# 100%|██████████| 1377/1377 [00:24<00:00, 56.31it/s]
# match
# True     1065
# False     312
# Name: count, dtype: int64
# 1065

# %% [markdown]
# ## Add the CARDS classification (0 to 7)

# %%
# Limit concurrency
semaphore = Semaphore(100)


async def classify_cards(
    text: str, quote: str
) -> Literal[
    "0_accepted",
    "1_its_not_happening",
    "2_humans_not_the_cause",
    "3_impacts_not_bad",
    "4_solutions_harmful_unnecessary",
    "5_science_uncertain",
    "6_proponents_biased",
    "7_fossil_fuels_needed",
]:
    messages = [
        {
            "role": "system",
            "content": """Tu es un expert en désinformation sur les questions environnementales, spécialiste en science climatique et bien informé sur le GIEC. L'utilisateur va te fournir un extrait de deux minutes d'une transcription d'un programme télévisé ou radiophonique. Dans cet extrait, nous avons repéré un passage qui pourrait contenir des propos climatosceptiques nécessitant un fack-checking. Ta mission est de classer ce passage dans la catégorie appropriée. Note que certains passages peuvent avoir été identifiés par erreur. Concentre-toi uniquement sur les passages clairement climatosceptiques. Si tu as un doute, attribue-les à la catégorie 0_accepted.

# Catégories prédéfinies

- 0_accepted: Le passage n'a pas de contenu climatosceptique évident et est accepté tel quel.
- 1_its_not_happening: Négation du réchauffement climatique ou allégations selon lesquelles les signes de changement climatique ne seraient pas avérés, tels que la fonte des glaces ou l'élévation du niveau de la mer.
- 2_humans_not_the_cause: Refus de reconnaître que les gaz à effet de serre produits par l'activité humaine sont la cause du changement climatique, attribuant plutôt cela à des variations naturelles ou autres phénomènes.
- 3_impacts_not_bad: Minimisation des impacts du changement climatique, suggérant qu'ils pourraient être bénins ou même bénéfiques.
- 4_solutions_harmful_unnecessary: Critique des solutions climatiques, affirmant qu'elles sont nuisibles, inutiles, ou inefficaces.
- 5_science_uncertain: Contestation de la validité de la science climatique, affirmant qu'elle est incertaine, biaisée ou peu fiable.
- 6_proponents_biased: Accusations de partialité ou de motivations politiques parmi les scientifiques et les défenseurs de l'action climatique, allant jusqu'à suggérer un alarmisme ou une conspiration.
- 7_fossil_fuels_needed: Arguments en faveur de l'utilisation continue des combustibles fossiles pour le développement économique et le maintien du niveau de vie.

# Exemples

## Exemple 0

<extrait>
[...]
</extrait>
<passage climatosceptique>
les scientifiques observent une hausse des températures mondiales, entraînant des changements climatiques visibles ils soulignent la nécessité d'agir pour en limiter les impacts
</passage climatosceptique>
<catégorie>0_accepted</catégorie>

## Exemple 1

<extrait>
[...]
</extrait>
<passage climatosceptique>
la fréquence des discussions sur la crise climatique semble augmenter mais certains experts proposent que les avertissements sur le climat pourraient être exagérés faisant souvent valoir que les fluctuations climatiques sont tout à fait naturelles et que les vérités scientifiques sont parfois altérées pour servir des intérêts politiques
</passage climatosceptique>
<catégorie>1_its_not_happening</catégorie>

## Exemple 2

<extrait>
[...]
</extrait>
<passage climatosceptique>
il est contesté que la contribution humaine aux niveaux de CO2 soit réellement significative certains experts soutiennent que les océans jouent un rôle bien plus important dans l'émission de ce gaz
</passage climatosceptique>
<catégorie>2_humans_not_the_cause</catégorie>

## Exemple 3

<extrait>
[...]
</extrait>
<passage climatosceptique>
il est important de noter que beaucoup de régions touchées par des événements climatiques extrêmes retrouvent leur équilibre naturel et peuvent même bénéficier de ces changements car plusieurs études montrent que certaines espèces et écosystèmes s'adaptent efficacement aux variations climatiques
</passage climatosceptique>
<catégorie>3_impacts_not_bad</catégorie>

## Exemple 4

<extrait>
[...]
</extrait>
<passage climatosceptique>
de nombreux experts remettent en question l'efficacité des initiatives visant à réduire la pollution, arguant qu'elles ne font qu'ajouter des coûts économiques sans réel impact positif sur l'environnement
</passage climatosceptique>
<catégorie>4_solutions_harmful_unnecessary</catégorie>

## Exemple 5

<extrait>
[...]
</extrait>
<passage climatosceptique>
En réfléchissant à la situation on peut voir un parallèle avec le débat climatique de nombreux sceptiques pensent que le discours autour du climat est devenu une sorte de dogme où la critique est difficilement tolérée
</passage climatosceptique>
<catégorie>5_science_uncertain</catégorie>

## Exemple 6

<extrait>
[...]
</extrait>
<passage climatosceptique>
Certains médias et politiciens utilisent la peur du changement climatique pour avancer des agendas politiques partisans, affirmant que les scientifiques amplifient les données pour obtenir plus de subventions.
</passage climatosceptique>
<catégorie>6_proponents_biased</catégorie>

## Exemple 7

<extrait>
[...]
</extrait>
<passage climatosceptique>
L'économie mondiale repose encore largement sur les combustibles fossiles, et leur abandon mettrait en péril notre développement économique et notre sécurité énergétique, car les énergies renouvelables ne sont pas encore prêtes à prendre le relais.
</passage climatosceptique>
<catégorie>7_fossil_fuels_needed</catégorie>""",
        },
        {
            "role": "user",
            "content": f"""<extrait>
{text}
</extrait>
<passage climatosceptique>
{quote}
</passage climatosceptique>""",
        },
    ]
    async with semaphore:
        response = await acompletion(
            "gpt-4o-mini",
            messages=messages,
            stop="</",
            temperature=0,
        )
    cards_class = response.choices[0].message.content.split("<catégorie>")[1]
    return cards_class

# %%
# Run the CARDS classification inference for all the claims
df["cards"] = await tqdm.gather(
    *[
        classify_cards(text, quote)
        for text, quote in df[["text", "quote"]].itertuples(index=False)
    ]
)
# Out:
# 100%|██████████| 1065/1065 [00:37<00:00, 28.64it/s]

# %%
# Save results to avoid recomputing them
df.to_csv("../../data/raw/4_channels_predictions_with_cards_09_2023_09_2024.csv")

# %%
# Reload the results (on notebook restart)
df = pd.read_csv(
    "../../data/raw/4_channels_predictions_with_cards_09_2023_09_2024.csv", index_col=0
)
df
# Out:
#                                                                   start  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  2023-09-04 05:56:00
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  2023-09-04 07:50:00
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  2023-09-06 07:22:00
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  2023-09-07 08:56:00
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  2023-09-08 19:34:00
# ...                                                                 ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  2024-07-24 09:08:00
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  2024-07-29 13:14:00
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  2024-08-05 09:16:00
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  2024-08-17 20:24:00
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  2024-08-26 13:32:00
#
#                                                                                                  text  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  série qu'on peut redire par fonction juré déjà...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  salle d'attente il y a toutes les classes rage...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  en france on peut quand même s'appuyer sur ce ...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  pour faire réussir nos enfants dans quel monde...
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  c'est non seulement que les utilisent pas mais...
# ...                                                                                               ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  de juin dans cette région le préfet a donc déc...
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  sur place voilà ce qu'ils restent par exemple ...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  les insectes non on pense que c'est la chaleur...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  le vaucluse ses problèmes d'étiquetage représe...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  de foot passant déclinent c'est un signe qui a...
#
#                                                    channel_name  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...      europe1
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...      europe1
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...      europe1
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...      europe1
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...      europe1
# ...                                                         ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...          tf1
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...          tf1
# cdfed233896d49971897df448465dd43b79ae871b33adb5...          tf1
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...          tf1
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...          tf1
#
#                                                     channel_is_radio  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...              True
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...              True
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...              True
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...              True
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...              True
# ...                                                              ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...             False
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...             False
# cdfed233896d49971897df448465dd43b79ae871b33adb5...             False
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...             False
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...             False
#
#                                                       channel_program_type  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  Information - Magazine
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  Information - Magazine
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  Information - Magazine
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  Information - Magazine
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  Information - Magazine
# ...                                                                    ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  Information - Magazine
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...   Information - Journal
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  Information - Magazine
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...   Information - Journal
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...   Information - Journal
#
#                                                           channel_program  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...                Bonjour
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...         Europe 1 Matin
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...         Europe 1 Matin
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...       L'heure des pros
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...                   Soir
# ...                                                                   ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  Bonjour ! La Matinale
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...                 JT 13h
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  Bonjour ! La Matinale
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...         JT 20h + météo
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...                 JT 13h
#
#                                                                                                themes  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  ["biodiversite_concepts_generaux", "changement...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  ["changement_climatique_causes", "changement_c...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  ["changement_climatique_consequences_indirecte...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...                  ["changement_climatique_constat"]
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  ["biodiversite_concepts_generaux", "biodiversi...
# ...                                                                                               ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  ["adaptation_climatique_solutions", "ressource...
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  ["changement_climatique_constat_indirectes", "...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  ["changement_climatique_constat_indirectes", "...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  ["biodiversite_concepts_generaux", "biodiversi...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  ["changement_climatique_causes_indirectes", "b...
#
#                                                                                              keywords  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  [{"keyword": "eaux", "timestamp": 169379984302...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  [{"keyword": "giec", "timestamp": 169380664205...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  [{"keyword": "incendies", "timestamp": 1693977...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  [{"keyword": "climatique", "timestamp": 169406...
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  [{"keyword": "d\u00e9carboner", "timestamp": 1...
# ...                                                                                               ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  [{"keyword": "agriculteur", "timestamp": 17218...
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  [{"keyword": "feux", "timestamp": 172225164506...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  [{"keyword": "g\u00e9othermie", "timestamp": 1...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  [{"keyword": "agriculteur", "timestamp": 17239...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  [{"keyword": "pollution", "timestamp": 1724671...
#
#                                                     num_keywords  num_tokens  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...             2         559
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...             2         554
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...             2         594
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...             1         563
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...             6         449
# ...                                                          ...         ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...             1         505
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...             1         446
# cdfed233896d49971897df448465dd43b79ae871b33adb5...             2         479
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...             1         494
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...             2         387
#
#                                                     ...  \
# id                                                  ...
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  ...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  ...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  ...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  ...
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  ...
# ...                                                 ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  ...
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  ...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  ...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  ...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  ...
#
#                                                                                               context  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  Dans un passage en parlant des personnages du ...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  Dans un extrait de programme où différents per...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  Lors d'une discussion sur le rôle des pharmaci...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  Le commentaire sur une polémique entre personn...
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  L'intervenant mentionne une perte de confiance...
# ...                                                                                               ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  Face à la menace que représentent les loups po...
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  Le journaliste fait état des enquêtes en cours...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  Il est mentionné que la climatisation, qui est...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  Un segment aborde une nouvelle tendance sur le...
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  L'intervenant suggère que la population de hér...
#
#                                                    contradiction  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...           NaN
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...           NaN
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...           NaN
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...           NaN
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...           NaN
# ...                                                          ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...           NaN
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...           NaN
# cdfed233896d49971897df448465dd43b79ae871b33adb5...           NaN
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...           NaN
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...           NaN
#
#                                                    disinformation_category  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...               consensus
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...               consensus
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...               narrative
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...               consensus
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...               consensus
# ...                                                                    ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...               consensus
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...               consensus
# cdfed233896d49971897df448465dd43b79ae871b33adb5...               consensus
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...               narrative
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...               consensus
#
#                                                    disinformation_score  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...                 high
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...                 high
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...                 high
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...                 high
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...                 high
# ...                                                                 ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...                 high
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...                 high
# cdfed233896d49971897df448465dd43b79ae871b33adb5...                 high
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...                 high
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...                 high
#
#                                                          pro_anti  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  anti-écologie
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  anti-écologie
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  anti-écologie
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  anti-écologie
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  anti-écologie
# ...                                                           ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  anti-écologie
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  anti-écologie
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  anti-écologie
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  anti-écologie
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  anti-écologie
#
#                                                                                                 quote  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  il y a par exemple le giec transhumaniste qui ...
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  il y a par exemple le giec transhumaniste qui ...
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  j'ai l'impression qu'il y a eu beaucoup de mor...
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  ...c'était hier soir dans cette à vous sur fra...
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  les climatologues ne croient plus leurs termes...
# ...                                                                                               ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...  nous on partirait plutôt sur de la capture eff...
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  d'après les autorités le feu serait d'origine ...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  le progrès sur le réchauffement climatique la ...
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...    Cette astuce elle est fausse et voilà pourquoi.
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  en théorie ça doit être parce qu'il y a une mo...
#
#                                                       speaker quote_start  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...  narrative        1533
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...  narrative         882
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...  narrative         264
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...  narrative         197
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  narrative         808
# ...                                                       ...         ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...      facts        1059
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...  narrative        1151
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  narrative        2004
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...  narrative        2130
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...  consensus         583
#
#                                                    quote_end  \
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...      1646
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...       957
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...       369
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...       308
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...       862
# ...                                                      ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...      1135
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...      1207
# cdfed233896d49971897df448465dd43b79ae871b33adb5...      2098
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...      2176
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...       649
#
#                                                                   cards
# id
# f17cb36a314156417616ef1ebb9232bbf203a1ecdc983c7...           0_accepted
# e57e39657004072e5f998d19e6a8a952ee8f35923b9072f...           0_accepted
# 5b7207073227562ad5fd7b252e290d0a2079f3cbbb2e5cd...           0_accepted
# 6c3bb9299d31332c644b54832399976117d28776c9e22ca...           0_accepted
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  5_science_uncertain
# ...                                                                 ...
# f58921002bc9d8158f722c26c510212340b1a1666fc2e58...           0_accepted
# f875741067fda8011d4aa9ad4c543e52227e31b525fed19...           0_accepted
# cdfed233896d49971897df448465dd43b79ae871b33adb5...    3_impacts_not_bad
# 6f48350bc56ebb262e90f9950e95de345ce69e3fb0053bf...           0_accepted
# e641edd619674384dd37c0f35d0dff55354a299f76e564c...           0_accepted
#
# [1065 rows x 22 columns]

# %%
# We can get rid of 60% of the claims that are likely false positives
display(df["cards"].value_counts().sort_index())
display(
    str(round((1 - (df["cards"] == "0_accepted").sum() / len(df)) * 100))
    + "% of the detected claims from the first LLM prompt are likely false positives "
)
df = df[df["cards"] != "0_accepted"].copy()
len(df)
# Out:
# cards
# 0_accepted                         501
# 1_its_not_happening                165
# 2_humans_not_the_cause              42
# 3_impacts_not_bad                   70
# 4_solutions_harmful_unnecessary    112
# 5_science_uncertain                 72
# 6_proponents_biased                 86
# 7_fossil_fuels_needed               17
# Name: count, dtype: int64
# '53% of the detected claims from the first LLM prompt are likely false positives '
# 564

# %% [markdown]
# ## Improve the Mediatree text readability for human review

# %%
# Limit concurrency
semaphore = Semaphore(100)


async def improve_mediatree_readability(text: str, quote: str) -> str:
    messages = [
        {
            "role": "system",
            "content": """L'utilisateur va fournir un extrait de 2 minutes d'une émission de télévision ou de radio ainsi qu'une citation extraite du texte. La transcription fournie peut manquer de ponctuation et être de qualité médiocre, avec un vocabulaire incorrect ou un découpage maladroit. Elle sera phonétique. Lorsque le texte semble incohérent, reformule-le en tenant compte de la phonétique, afin d'obtenir un texte final en français correct.

## Exemple

<extrait>
les les energie renouvellable doive etre remi euh en question en europ sané col debuts
</extrait>
<citation à mettre en gras>sané col debuts</citation à mettre en gras>"
<extrait corrigé>
Les énergies renouvelables doivent être remises en question en Europe, **et ça n'est que le début !**
</extrait corrigé>

## Notes

Le format de sortie doit être en Markdown, avec la citation extraite du texte **<citation>** mise en gras dans l'extrait corrigé.
""",
        },
        {
            "role": "user",
            "content": f"""<extrait>
{text}
</extrait>
<citation à mettre en gras>
{quote}
</citation à mettre en gras>""",
        },
    ]
    async with semaphore:
        response = await acompletion(
            "gpt-4o-mini",
            messages=messages,
            stop="</",
            temperature=0,
        )
    fixed_text = (
        response.choices[0].message.content.split("<extrait corrigé>")[1].strip()
    )
    return fixed_text

# %%
# Run the text improvement inference for all the claims
df["improved_text_with_quote"] = await tqdm.gather(
    *[
        improve_mediatree_readability(text, quote)
        for text, quote in df[["text", "quote"]].itertuples(index=False)
    ]
)
# Out:
# 100%|██████████| 564/564 [00:49<00:00, 11.32it/s]

# %%
# Save results to avoid recomputing
df.to_csv(
    "../../data/raw/4_channels_predictions_with_cards_rewritten_09_2023_09_2024.csv"
)

# %%
# Reload the results (on notebook restart)
df = pd.read_csv(
    "../../data/raw/4_channels_predictions_with_cards_rewritten_09_2023_09_2024.csv",
    index_col=0,
)
df
# Out:
#                                                                   start  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  2023-09-08 19:34:00
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  2023-09-15 19:30:00
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  2023-09-20 07:50:00
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  2023-10-02 07:54:00
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  2023-10-05 19:54:00
# ...                                                                 ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...  2024-04-23 20:36:00
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  2024-04-28 20:40:00
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  2024-06-16 18:04:00
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  2024-07-21 17:14:00
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  2024-08-05 09:16:00
#
#                                                                                                  text  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  c'est non seulement que les utilisent pas mais...
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  jusqu'au trente septembre détaille sofia au qu...
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  tente d'échapper à une tempête de pluie d'acid...
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  de français n'arrive pas à se loger c'est offi...
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  climatique le réchauffement collecte de grenob...
# ...                                                                                               ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...  plus chaud de ces dix dernières années le temp...
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  hui ce fameux pacte d'immigration qui a été vo...
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  avec l'aide de nos fournisseurs et si il s'avè...
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  france plusieurs millions de maison menace de ...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  les insectes non on pense que c'est la chaleur...
#
#                                                    channel_name  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...      europe1
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...      europe1
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...      europe1
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...      europe1
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...      europe1
# ...                                                         ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...          tf1
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...          tf1
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...          tf1
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...          tf1
# cdfed233896d49971897df448465dd43b79ae871b33adb5...          tf1
#
#                                                     channel_is_radio  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...              True
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...              True
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...              True
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...              True
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...              True
# ...                                                              ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...             False
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...             False
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...             False
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...             False
# cdfed233896d49971897df448465dd43b79ae871b33adb5...             False
#
#                                                       channel_program_type  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  Information - Magazine
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  Information - Magazine
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  Information - Magazine
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  Information - Magazine
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  Information - Magazine
# ...                                                                    ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...   Information - Journal
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...   Information - Journal
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  Information - Magazine
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  Information - Magazine
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  Information - Magazine
#
#                                                           channel_program  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...                   Soir
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...                   Soir
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...         Europe 1 Matin
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...         Europe 1 Matin
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...                   Soir
# ...                                                                   ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...         JT 20h + météo
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...         JT 20h + météo
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...       Sept à huit Life
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...       Sept à huit Life
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  Bonjour ! La Matinale
#
#                                                                                                themes  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  ["biodiversite_concepts_generaux", "biodiversi...
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  ["biodiversite_concepts_generaux", "ressources...
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  ["biodiversite_concepts_generaux", "biodiversi...
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  ["changement_climatique_causes", "changement_c...
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  ["changement_climatique_constat_indirectes", "...
# ...                                                                                               ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...  ["changement_climatique_consequences_indirecte...
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  ["ressources_indirectes", "ressources_solution...
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  ["ressources_solutions_indirectes", "biodivers...
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  ["biodiversite_concepts_generaux", "changement...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  ["changement_climatique_constat_indirectes", "...
#
#                                                                                              keywords  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  [{"keyword": "d\u00e9carboner", "timestamp": 1...
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  [{"keyword": "terre", "timestamp": 16947991040...
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  [{"keyword": "acide", "timestamp": 16951890010...
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  [{"keyword": "eaux", "timestamp": 169622615203...
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  [{"keyword": "terre", "timestamp": 16965285020...
# ...                                                                                               ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...  [{"keyword": "planter des arbres", "timestamp"...
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  [{"keyword": "agriculteur", "timestamp": 17143...
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  [{"keyword": "huile de palme", "timestamp": 17...
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  [{"keyword": "naturel", "timestamp": 172157485...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  [{"keyword": "g\u00e9othermie", "timestamp": 1...
#
#                                                     num_keywords  num_tokens  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...             6         449
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...             2         533
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...             3         545
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...             6         573
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...             1         499
# ...                                                          ...         ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...             5         367
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...             2         614
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...             3         359
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...             1         360
# cdfed233896d49971897df448465dd43b79ae871b33adb5...             2         479
#
#                                                     ...  \
# id                                                  ...
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  ...
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  ...
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  ...
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  ...
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  ...
# ...                                                 ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...  ...
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  ...
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  ...
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  ...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  ...
#
#                                                                                         contradiction  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...                                                NaN
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...                                                NaN
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...                                                NaN
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...                                                NaN
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  Elle contredit les impacts largement documenté...
# ...                                                                                               ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...                                                NaN
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...                                                NaN
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...                                                NaN
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  Les scientifiques affirment que le changement ...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...                                                NaN
#
#                                                    disinformation_category  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...               consensus
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...               consensus
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...               consensus
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...               narrative
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...               consensus
# ...                                                                    ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...               consensus
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...               narrative
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...               consensus
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...               consensus
# cdfed233896d49971897df448465dd43b79ae871b33adb5...               consensus
#
#                                                    disinformation_score  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...                 high
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...                 high
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...                 high
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...                 high
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...                 high
# ...                                                                 ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...                 high
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...                 high
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...                 high
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...                 high
# cdfed233896d49971897df448465dd43b79ae871b33adb5...                 high
#
#                                                          pro_anti  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  anti-écologie
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  anti-écologie
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  anti-écologie
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  anti-écologie
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  anti-écologie
# ...                                                           ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...  anti-écologie
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  anti-écologie
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  anti-écologie
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  anti-écologie
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  anti-écologie
#
#                                                                                                 quote  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  les climatologues ne croient plus leurs termes...
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  Il y a beaucoup de soldats poneys menteurs à t...
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  tempête de pluie d'acide mortelle selon l'inrs...
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  Ça va de l'interdiction des avions d'affaires ...
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  on ne peut pas faire le lien directement avec ...
# ...                                                                                               ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...                 Il n'y a plus ni eau ni printemps.
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  ce tsunami de normes de contraintes de taxe qu...
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  l'entreprise n'a pas voulu nous dire combien d...
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...       le dérèglement climatique phénomène naturel.
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  le progrès sur le réchauffement climatique la ...
#
#                                                       speaker quote_start  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  narrative         808
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  narrative        1800
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...      other          23
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  consensus         806
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  consensus        1316
# ...                                                       ...         ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...  consensus         114
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  narrative        1492
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...      facts         173
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  consensus         180
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  narrative        2004
#
#                                                    quote_end  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...       862
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...      1891
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...       132
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...       947
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...      1378
# ...                                                      ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...       148
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...      1625
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...       340
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...       225
# cdfed233896d49971897df448465dd43b79ae871b33adb5...      2098
#
#                                                                               cards  \
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...              5_science_uncertain
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...              5_science_uncertain
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...              1_its_not_happening
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...                3_impacts_not_bad
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...           2_humans_not_the_cause
# ...                                                                             ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...              1_its_not_happening
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  4_solutions_harmful_unnecessary
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  4_solutions_harmful_unnecessary
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...           2_humans_not_the_cause
# cdfed233896d49971897df448465dd43b79ae871b33adb5...                3_impacts_not_bad
#
#                                                                              improved_text_with_quote
# id
# 52061c3902c0257c7bfae7086ae50ea3998fea4204bcd66...  Ce n'est pas seulement qu'ils ne les utilisent...
# 34a41bf34b35ee91fc147601fb8c21a366a2f568b9060bb...  Jusqu'au trente septembre, détaille Sofia au q...
# 0fb8db32982baea27fa4a92220e76331e703d61852c0e8d...  On tente d'échapper à une **tempête de pluie d...
# 4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3a...  Les Français n'arrivent pas à se loger, c'est ...
# 74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b5...  Le réchauffement climatique a été collecté à G...
# ...                                                                                               ...
# 22d30e47c43d8defe1bdab51e6e4c6374ba982d76de8896...  Plus chaud de ces dix dernières années, le tem...
# 58feacdc4a4d31023a87bce158ee902d37076d9f5562f3f...  Aujourd'hui, ce fameux pacte d'immigration qui...
# 6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c34...  Avec l'aide de nos fournisseurs, si il s'avère...
# 0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9e...  En France, plusieurs millions de maisons sont ...
# cdfed233896d49971897df448465dd43b79ae871b33adb5...  Les insectes, non, on pense que c'est la chale...
#
# [564 rows x 23 columns]

# %%
# Remove the few claims that came up with multiple or no quotes in bold
display((df["improved_text_with_quote"].str.count(r"\*\*") != 2).sum())
df = df[df["improved_text_with_quote"].str.count(r"\*\*") == 2].copy()
# Out:
# np.int64(19)

# %% [markdown]
# ## Create Excel file for human review

# %%
# Keep only interesting columns
review_df = df.reset_index()
review_df = review_df[
    [
        "id",
        "channel_name",
        "start",
        "improved_text_with_quote",
        "quote",
        "claim",
        "analysis",
        "context",
        "cards",
    ]
].rename(columns={"improved_text_with_quote": "text"})

# Sort extracts in case there are follow-up extracts
review_df = review_df.sort_values(by=["channel_name", "start"])

review_df
# Out:
#                                                     id channel_name  \
# 0    52061c3902c0257c7bfae7086ae50ea3998fea4204bcd6...      europe1
# 1    34a41bf34b35ee91fc147601fb8c21a366a2f568b9060b...      europe1
# 2    0fb8db32982baea27fa4a92220e76331e703d61852c0e8...      europe1
# 3    4792f93c6614b1e7ef39e301cc6c1d0f4d3d18b9421cc3...      europe1
# 4    74c05fdbca4aeffb643abf0de486b57f8299051d4ef71b...      europe1
# ..                                                 ...          ...
# 540  22d30e47c43d8defe1bdab51e6e4c6374ba982d76de889...          tf1
# 541  58feacdc4a4d31023a87bce158ee902d37076d9f5562f3...          tf1
# 542  6d39a0d45c359fd2183c0f1f001b76c4b60d283240e5c3...          tf1
# 543  0718ef4df3559735ad33436f7e1e39802a71d923cbc0b9...          tf1
# 544  cdfed233896d49971897df448465dd43b79ae871b33adb...          tf1
#
#                    start                                               text  \
# 0    2023-09-08 19:34:00  Ce n'est pas seulement qu'ils ne les utilisent...
# 1    2023-09-15 19:30:00  Jusqu'au trente septembre, détaille Sofia au q...
# 2    2023-09-20 07:50:00  On tente d'échapper à une **tempête de pluie d...
# 3    2023-10-02 07:54:00  Les Français n'arrivent pas à se loger, c'est ...
# 4    2023-10-05 19:54:00  Le réchauffement climatique a été collecté à G...
# ..                   ...                                                ...
# 540  2024-04-23 20:36:00  Plus chaud de ces dix dernières années, le tem...
# 541  2024-04-28 20:40:00  Aujourd'hui, ce fameux pacte d'immigration qui...
# 542  2024-06-16 18:04:00  Avec l'aide de nos fournisseurs, si il s'avère...
# 543  2024-07-21 17:14:00  En France, plusieurs millions de maisons sont ...
# 544  2024-08-05 09:16:00  Les insectes, non, on pense que c'est la chale...
#
#                                                  quote  \
# 0    les climatologues ne croient plus leurs termes...
# 1    Il y a beaucoup de soldats poneys menteurs à t...
# 2    tempête de pluie d'acide mortelle selon l'inrs...
# 3    Ça va de l'interdiction des avions d'affaires ...
# 4    on ne peut pas faire le lien directement avec ...
# ..                                                 ...
# 540                 Il n'y a plus ni eau ni printemps.
# 541  ce tsunami de normes de contraintes de taxe qu...
# 542  l'entreprise n'a pas voulu nous dire combien d...
# 543       le dérèglement climatique phénomène naturel.
# 544  le progrès sur le réchauffement climatique la ...
#
#                                                  claim  \
# 0    Les climatologues ne croient plus leurs termes...
# 1    Il y a beaucoup de soldats poneys menteurs à t...
# 2    tempête de pluie d'acide mortelle enregistrée ...
# 3    Diminuer le nombre de vaches et contrôler les ...
# 4    On ne peut pas faire le lien directement avec ...
# ..                                                 ...
# 540                 Il n'y a plus ni eau ni printemps.
# 541   Le pacte vert européen organise la décroissance.
# 542  L'huile de palme serait aujourd'hui une soluti...
# 543  Le dérèglement climatique est un phénomène nat...
# 544  La climatisation industrialisée a été une répo...
#
#                                               analysis  \
# 0    Cette affirmation pourrait créer un doute sur ...
# 1    Cette allégation semble suggérer que le réchau...
# 2    L'allégation mentionne une tempête de pluie d'...
# 3    Cette affirmation présente des mesures qui n'o...
# 4    Cette assertion minimise le consensus scientif...
# ..                                                 ...
# 540  Cette affirmation semble exagérée et pourrait ...
# 541  Cette affirmation attribue une intention de dé...
# 542  Cette allégation semble minimiser les impacts ...
# 543  Cette affirmation contredit le consensus scien...
# 544  Ce claim fait l'impasse sur le fait que la gén...
#
#                                                context  \
# 0    L'intervenant mentionne une perte de confiance...
# 1    Lors d'une conférence de presse au Vietnam, le...
# 2    Dans une discussion sur un film catastrophe éc...
# 3    L'interlocuteur mentionne plusieurs mesures ex...
# 4    Luc Moreau énonce lui-même qu'il est difficile...
# ..                                                 ...
# 540  L'orateur évoque un changement climatique qui ...
# 541  Lors d'un discours critique à l'égard des poli...
# 542  Dans un débat sur les pratiques de certains fo...
# 543  Une affirmation selon laquelle les changements...
# 544  Il est mentionné que la climatisation, qui est...
#
#                                cards
# 0                5_science_uncertain
# 1                5_science_uncertain
# 2                1_its_not_happening
# 3                  3_impacts_not_bad
# 4             2_humans_not_the_cause
# ..                               ...
# 540              1_its_not_happening
# 541  4_solutions_harmful_unnecessary
# 542  4_solutions_harmful_unnecessary
# 543           2_humans_not_the_cause
# 544                3_impacts_not_bad
#
# [545 rows x 9 columns]

# %%
# Pandas dataframe to Excel
writer = pd.ExcelWriter(
    "../../data/raw/4_channels_review_09_2023_09_2024.xlsx", engine="openpyxl"
)
review_df.to_excel(writer, sheet_name="Claims review", index=False)

workbook: Workbook = writer.book
worksheet: Worksheet = writer.sheets["Claims review"]

# Styling: Wrap text + vertical align top
for rows in worksheet.iter_rows():
    for cell in rows:
        cell.alignment = Alignment(wrapText=True, vertical="top")

# Replace the "text" column with a bolded version
for i, text in enumerate(review_df["text"], start=2):
    # Find quote start and end using the **bold** markers
    bold_search = re.search(r"\*\*(.*?)\*\*", text, flags=re.M)
    quote_start = bold_search.start()
    quote_end = bold_search.end()

    # "text" will be in the "D" column
    column_letter = get_column_letter(review_df.columns.tolist().index("text") + 1)
    row_number = str(i)
    worksheet[f"{column_letter}{row_number}"] = CellRichText(
        text[:quote_start],
        TextBlock(InlineFont(b=True), text[quote_start:quote_end].replace("**", "")),
        text[quote_end:],
    )

# Adjust column widths
column_widths = {
    "id": 12,
    "channel_name": 15,
    "start": 20,
    "text": 80,
    "quote": 25,
    "claim": 25,
    "analysis": 30,
    "context": 30,
    "cards": 25,
}
for col, width in column_widths.items():
    worksheet.column_dimensions[
        get_column_letter(review_df.columns.tolist().index(col) + 1)
    ].width = width

writer.close()
