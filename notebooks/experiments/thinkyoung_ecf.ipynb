# %%
import asyncio
import difflib
import json
import sys
from functools import wraps

import pandas as pd
import plotly.io
from litellm import acompletion, completion_cost
from pydantic import BaseModel
from tqdm.asyncio import tqdm
from unidecode import unidecode

sys.path.append("../..")

plotly.io.renderers.default = "png"

# %% [markdown]
# ## Make predictions for one month (07/2024)

# %%
# Load data
df = pd.read_parquet("../../data/raw/18_channels_2023_09_to_2024_09.parquet")

# Filter some channels only
df = df[df["channel_name"].isin(["sud-radio", "europe1", "itele"])]
# df = df[(df["start"] >= "2024-07-01") & (df["start"] < "2024-08-01")]

# Fixing some syntax issues in the data
# Mediatree issue with "' "
df["text"] = df["text"].str.replace("' ", "'")

df
# Out:
#                                                                  start  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be... 2023-09-01 06:26:00
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9... 2023-09-01 06:50:00
# b6d54aefb250671e7754a688411ce9e68badcad88a665be... 2023-09-01 07:38:00
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665... 2023-09-01 08:44:00
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412... 2023-09-01 08:46:00
# ...                                                                ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051... 2024-09-12 07:06:00
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b... 2024-09-12 08:00:00
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793... 2024-09-12 09:00:00
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf... 2024-09-12 11:48:00
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0... 2024-09-12 13:06:00
#
#                                                                                                  text  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  <unk> <unk> <unk> <unk> aerosmith en janvier m...
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  la très grande majorité d'entre eux ne connais...
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...  mais titeuf ne vieillit pas le monde change ti...
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  dû travailler très vite le journal arrive à no...
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  pas avoir lieu ni même européens existait ni l...
# ...                                                                                               ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051...  est la période la plus à risque pour les inond...
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b...  solaire point fr votre expert en panneaux sola...
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793...  foyer trois mille neuf cent quatre-vingt-dix e...
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf...  vous aimeriez tester tous les milieux b quatre...
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0...  jean paul briguer li et cécile chabaud euh cél...
#
#                                                    channel_name  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...      europe1
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...      europe1
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...      europe1
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...      europe1
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...      europe1
# ...                                                         ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051...    sud-radio
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b...    sud-radio
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793...    sud-radio
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf...    sud-radio
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0...    sud-radio
#
#                                                     channel_is_radio  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...              True
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...              True
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...              True
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...              True
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...              True
# ...                                                              ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051...              True
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b...              True
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793...              True
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf...              True
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0...              True
#
#                                                       channel_program_type  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  Information - Magazine
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  Information - Magazine
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...  Information - Magazine
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  Information - Magazine
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  Information - Magazine
# ...                                                                    ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051...  Information - Magazine
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b...  Information - Magazine
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793...  Information - Magazine
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf...  Information - Magazine
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0...  Information - Magazine
#
#                                                                   channel_program  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...                        Bonjour
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...                        Bonjour
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...                 Europe 1 Matin
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...                 Europe 1 Matin
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...                 Europe 1 Matin
# ...                                                                           ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051...                 Le Grand Matin
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b...                 Le Grand Matin
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793...                 Le Grand Matin
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf...           Mettez-vous d'accord
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0...  Sud Radio dans tous ses états
#
#                                                                                                themes  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  ["biodiversite_concepts_generaux", "adaptation...
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  ["biodiversite_concepts_generaux", "changement...
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...                  ["changement_climatique_constat"]
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  ["biodiversite_concepts_generaux", "ressources...
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  ["biodiversite_concepts_generaux", "changement...
# ...                                                                                               ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051...  ["adaptation_climatique_solutions", "changemen...
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b...  ["ressources_solutions", "changement_climatiqu...
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793...  ["ressources_solutions", "changement_climatiqu...
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf...  ["biodiversite_solutions_indirectes", "changem...
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0...  ["attenuation_climatique_solutions", "attenuat...
#
#                                                                                              keywords  \
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...  [{"keyword": "eaux", "timestamp": 169354246806...
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...  [{"keyword": "eaux", "timestamp": 169354380309...
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...  [{"keyword": "bilan carbone", "timestamp": 169...
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...  [{"keyword": "eaux", "timestamp": 169355074908...
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...  [{"keyword": "\u00e9cologiste", "timestamp": 1...
# ...                                                                                               ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051...  [{"keyword": "inondation", "timestamp": 172611...
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b...  [{"keyword": "panneaux solaires", "timestamp":...
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793...  [{"keyword": "panneaux solaires", "timestamp":...
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf...  [{"keyword": "panneaux solaires", "timestamp":...
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0...  [{"keyword": "panneaux solaires", "timestamp":...
#
#                                                     num_keywords  num_tokens
# id
# 1dcd4b454f8bac42440259ce26a1a2192051186bb5728be...             1         383
# 0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc9...             3         593
# b6d54aefb250671e7754a688411ce9e68badcad88a665be...             1         606
# 23c2d3b292d9ab0fb0d0b2b8c34f3b88708c79ffab2d665...             3         515
# 71df0ce2b34afa23391d8e31d35ccd213ae2a881b7ce412...             2         536
# ...                                                          ...         ...
# 121c2c2780f373e0d03ad266a5b4c11e87873e353954051...             2         575
# 10e4d16cad946340c67738bdaa487603d4635c6d2db978b...             1         526
# 74f1b824b772877e6e05908a308a8ae31146b652ff50793...             1         520
# dbb0ba82809710c830b2170abb1d30b4b0b07650b3fdadf...             1         517
# 20c4542e60ad3387caaf54ad7cb4def5a98af162bbfb9c0...             1         544
#
# [34519 rows x 10 columns]

# %%
from openai import AsyncOpenAI

client = AsyncOpenAI()

# Limit concurrent requests to avoid API rate limiting
# (it depends on the model you use and your API tier)
semaphore = asyncio.Semaphore(100)


# Decorator that ensures `acompletion` uses the semaphore
def with_semaphore(acquire_semaphore):
    def decorator(func):
        @wraps(func)
        async def wrapper(*args, **kwargs):
            async with acquire_semaphore:
                return await func(*args, **kwargs)

        return wrapper

    return decorator


acompletion = with_semaphore(semaphore)(acompletion)


class MediatreePrediction(BaseModel):
    label_pred: str
    prompt_tokens: int
    completion_tokens: int
    total_tokens: int
    cost: float
    claim_pred: str | None = None


class Claim(BaseModel):
    claim: str
    context: str
    analysis: str
    disinformation_score: str
    disinformation_category: str
    pro_anti: str
    speaker: str
    contradiction: str
    quote: str


class Claims(BaseModel):
    claims: list[Claim]


async def detect_claims(transcription):
    prompt = f"""Tu es expert en désinformation sur les sujets environnementaux, expert en science climatique et sachant tout sur le GIEC. Je vais te donner un extrait d'une retranscription de 2 minutes d'un flux TV ou Radio. 
A partir de cet extrait liste moi tous les faits/opinions environnementaux (claim) uniques qu'il faudrait factchecker. Et pour chaque claim, donne une première analyse si c'est de la désinformation ou non, un score si c'est de la désinformation, ainsi qu'une catégorisation de cette allégation.
Ne sélectionne que les claims sur les thématiques environnementales (changement climatique, transition écologique, énergie, biodiversité, pollution, pesticides, ressources (eau, minéraux, ..) et pas sur les thématiques sociales et/ou économiques
Renvoie le résultat en json sans autre phrase d'introduction ou de conclusion avec à chaque fois les champs suivants : 

- "claim" - l'allégation à potentiellement vérifier
- "context" - reformulation du contexte dans laquelle cette allégation a été prononcée (maximum 1 paragraphe)
- "analysis" - première analyse du point de vue de l'expert sur le potentiel de désinformation de cette allégation en fonction du contexte
- "disinformation_score" - le score de désinformation (voir plus bas)
- "disinformation_category" - la catégorie de désinformation (voir plus bas)
- "pro_anti" - si l'allégation est plutôt anti-écologie ou pro-écologie
- "speaker" - nom et fonction de la personne qui a prononcé l'allégation si on a l'information (sinon "N/A")
- "contradiction" - si l'allégation a été contestée dans un dialogue, résume la contradiction (sinon "N/A")
- "quote" - la citation exacte qui correspond à l'allégation

Pour les scores "disinformation_score"
- "very low" = pas de problème, l'allégation n'est pas trompeuse ou à risque. pas besoin d'investiguer plus loin
- "low" = allégation qui nécessiterait une vérification et une interrogation, mais sur un sujet peu important et significatif dans le contexte des enjeux écologiques (exemple : les tondeuses à gazon, 
- "medium" = allégation problématique sur un sujet écologique important (scientifique, impacts, élections, politique, transport, agriculture, énergie, alimentation, démocratie ...) , qui nécessiterait vraiment d'être vérifiée, déconstruite, débunkée et interrogée. En particulier pour les opinions fallacieuses
- "high" = allégation grave, en particulier si elle nie le consensus scientifique

Pour les catégories de désinformation "disinformation_category": 
- "consensus" = négation du consensus scientifique
- "facts" = fait à vérifier, à préciser ou contextualiser
- "narrative" = narratif fallacieux ou opinion qui sème le doute (par exemple : "les écolos veulent nous enlever nos libertés")
- "other"

<transcription>
{transcription}
</transcription>
    """
    async with semaphore:
        # Retry if errors
        while True:
            try:
                completion = await client.beta.chat.completions.parse(
                    model="gpt-4o-mini",
                    messages=[
                        {
                            "role": "user",
                            "content": prompt,
                        }
                    ],
                    response_format=Claims,
                )
                break
            except Exception:
                print("Error, retrying...")

    n_tokens = completion.usage.total_tokens
    claims_data = completion.choices[0].message.parsed
    result = [claim.dict() for claim in claims_data.claims]

    return result

# %%
# Make predictions
mediatree_predictions: list[MediatreePrediction] = await tqdm.gather(
    *[detect_claims(text) for text in df["text"]]
)
# mediatree_predictions_df = pd.DataFrame(
#     [pred.model_dump(exclude_none=True) for pred in mediatree_predictions],
#     index=df.index,
# )
# df = pd.concat([df, mediatree_predictions_df], axis=1)
# Out:
# 100%|██████████| 34519/34519 [18:25<00:00, 31.24it/s]

# %%
df["claims"] = mediatree_predictions
# df["claims"] = df["claims"].apply(lambda x: x.to_dict(orient="records"))

# %%
df["label_pred"].value_counts()
# Out:
# label_pred
# 0_accepted                 12332
# 3_its_not_bad                513
# 1_its_not_happening          333
# 5_science_is_unreliable      266
# 4_solutions_wont_work        259
# 2_its_not_us                  57
# Name: count, dtype: int64

# %%
(df["label_pred"] != "0_accepted").sum()
# Out:
# np.int64(1428)

# %%
# Save the result
df.to_parquet(
    "../../data/experiments/label_studio_review/3_channels_predictions_09_2023_09_2024.parquet"
)

# %%
(df["claims"].str.len() > 1).sum()
# Out:
# np.int64(14526)

# %%
claims_list = df["claims"].tolist()

# %%
for id, claims_sublist in zip(df.index, claims_list):
    for claim in claims_sublist:
        claim["id"] = id

# %%
c = [l for sl in claims_list for l in sl]

# %%
cdf = pd.DataFrame(c)

# %%
cdf
# Out:
#                                                    claim  \
# 0      les initiatives positives de jean z une nova s...
# 1      Les propriétaires de campings peuvent réaliser...
# 2      Le nombre de campings équipés de douches conne...
# 3      Les limitations de douches ne sont plus vues c...
# 4            Titeuf explique ce qu'est le bilan carbone.
# ...                                                  ...
# 59295  Il ne faut pas tenter d'aller chercher son enf...
# 59296  Les baisses vitres qui sont électriques peuven...
# 59297  les températures sont descendues entre trois e...
# 59298  Les panneaux solaires permettent de faire des ...
# 59299  Il existe des offres sur l'isolation et le cha...
#
#                                                  context  \
# 0      L'interview mentionne des initiatives sur la g...
# 1      Le locuteur explique qu'une innovation dans le...
# 2      Lors de la discussion sur les innovations dans...
# 3      Le locuteur évoque un changement d'attitude de...
# 4      Lors d'une discussion sur les sujets abordés d...
# ...                                                  ...
# 59295  Eric Porte, à la tête du centre d'information ...
# 59296  Christophe Mirmand, préfet de la région Paca, ...
# 59297  L'intervenant décrit les conditions climatique...
# 59298  Cette allégation a été faite dans le cadre d'u...
# 59299  L'annonce mentionne des offres spécifiques sur...
#
#                                                 analysis disinformation_score  \
# 0      L'allégation semble promouvoir des pratiques p...                  low
# 1      Cette affirmation est généralement vérifiable ...                  low
# 2      Ceci est une information qui peut être vérifié...                  low
# 3      Cette observation peut refléter un phénomène s...               medium
# 4      L'allégation sur le fait que Titeuf peut expli...                  low
# ...                                                  ...                  ...
# 59295  Cette recommandation s'inscrit dans une logiqu...                  low
# 59296  Cette déclaration est réaliste et met en lumiè...                  low
# 59297  Cette allégation est factuelle et se réfère au...             very low
# 59298  Cette allégation est généralement exacte, car ...             very low
# 59299  Cette allégation nécessite vérification par ra...                  low
#
#       disinformation_category      pro_anti  \
# 0                       facts  pro-écologie
# 1                       facts  pro-écologie
# 2                       facts  pro-écologie
# 3                   narrative  pro-écologie
# 4                       facts  pro-écologie
# ...                       ...           ...
# 59295                   other  pro-écologie
# 59296                   other  pro-écologie
# 59297                   facts           N/A
# 59298                   facts  pro-écologie
# 59299                   facts  pro-écologie
#
#                                                  speaker contradiction  \
# 0      Emmanuel Kessler, directeur de la rédaction du...           N/A
# 1                                                    N/A           N/A
# 2                                                    N/A           N/A
# 3                                                    N/A           N/A
# 4                                                    N/A           N/A
# ...                                                  ...           ...
# 59295  Eric Porte, centre d'information pour la préve...           N/A
# 59296       Christophe Mirmand, préfet de la région Paca           N/A
# 59297          Rémi Fraisse, expert en panneaux solaires           N/A
# 59298                                                N/A           N/A
# 59299                                                N/A           N/A
#
#                                                    quote  \
# 0      les initiatives positives de jean z une nova s...
# 1      la facture s'allège de manière non négligeable...
# 2      le nombre de camping équipé a doublé depuis l'...
# 3      les propriétaires et les campeurs ne considère...
# 4      j'ai bien aimé dessinées titeuf qui explique c...
# ...                                                  ...
# 59295  Il ne faut pas tenter d'aller chercher son enf...
# 59296  Les baisses vitres qui sont électriques peuven...
# 59297  les températures sont descendues entre trois e...
# 59298  Les panneaux solaires permettent de faire des ...
# 59299  Il existe des offres sur l'isolation et le cha...
#
#                                                       id
# 0      1dcd4b454f8bac42440259ce26a1a2192051186bb5728b...
# 1      0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc...
# 2      0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc...
# 3      0eb5805fa23e0819f817ea10fe1fccd19e61e40a1239cc...
# 4      b6d54aefb250671e7754a688411ce9e68badcad88a665b...
# ...                                                  ...
# 59295  121c2c2780f373e0d03ad266a5b4c11e87873e35395405...
# 59296  121c2c2780f373e0d03ad266a5b4c11e87873e35395405...
# 59297  10e4d16cad946340c67738bdaa487603d4635c6d2db978...
# 59298  74f1b824b772877e6e05908a308a8ae31146b652ff5079...
# 59299  74f1b824b772877e6e05908a308a8ae31146b652ff5079...
#
# [59300 rows x 10 columns]

# %%
cdf = cdf[cdf["disinformation_score"] == "high"]

# %%
cdf["id"].nunique()
# Out:
# 1560

# %%
def show_llm_usage(df: pd.DataFrame) -> None:
    print("\nLLM USAGE\n=========\n")
    print(
        f"Median token usage:\n- Prompt: {int(df["prompt_tokens"].median())}\n"
        f"- Completion: {int(df["completion_tokens"].median())}\n"
        f"- Total: {int(df["total_tokens"].median())}"
    )
    print(f"\nTotal cost: ${df["cost"].sum():.3f}\n")


show_llm_usage(df)
# Out:
# LLM USAGE
# =========
#
# Median token usage:
# - Prompt: 1402
# - Completion: 27
# - Total: 1433
#
# Total cost: $3.126

# %%
df["label_pred"].value_counts()
# Out:
# label_pred
# 0_accepted                 12332
# 3_its_not_bad                513
# 1_its_not_happening          333
# 5_science_is_unreliable      266
# 4_solutions_wont_work        259
# 2_its_not_us                  57
# Name: count, dtype: int64

# %% [markdown]
# ## Manually review the predictions with LabelStudio

# %%
df = pd.read_csv(
    "../../data/experiments/label_studio_review/mediatree_predictions_07_2024.csv",
    index_col=0,
)
df
# Out:
#                                                                   start  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...  2024-01-01 06:02:00
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...  2024-01-01 06:14:00
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...  2024-01-01 06:36:00
# d346e52092308430d6ec6faa668722219ce024db394c112...  2024-01-01 06:54:00
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...  2024-01-01 07:02:00
# ...                                                                 ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...  2024-07-31 10:04:00
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...  2024-07-31 10:58:00
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...  2024-07-31 11:00:00
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...  2024-07-31 11:28:00
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...  2024-07-31 13:02:00
#
#                                                                                                  text  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...  sur la boisson maintenant que les fêtes sont a...
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...  première prescription culture de l'année c'est...
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...  hamas hier soir c'était donc un réveillon dans...
# d346e52092308430d6ec6faa668722219ce024db394c112...  d'accélérer cette part du made in france mais ...
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...  qui porte bonheur pour moi le quatre août deux...
# ...                                                                                               ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...  dans toute la france le bureau de recherches g...
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...  servi de point fr pourquoi venir chez castoram...
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...  triathlon et la dix neuvième médaille pour la ...
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...  de la sécurité sociale vous avez encore deux m...
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...  une étude de l'institut wtw le salaire médian ...
#
#                                                    channel_name  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...      europe1
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...      europe1
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...      europe1
# d346e52092308430d6ec6faa668722219ce024db394c112...      europe1
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...      europe1
# ...                                                         ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...    sud-radio
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...    sud-radio
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...    sud-radio
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...    sud-radio
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...    sud-radio
#
#                                                     channel_is_radio  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...              True
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...              True
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...              True
# d346e52092308430d6ec6faa668722219ce024db394c112...              True
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...              True
# ...                                                              ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...              True
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...              True
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...              True
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...              True
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...              True
#
#                                                       channel_program_type  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...  Information - Magazine
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...  Information - Magazine
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...  Information - Magazine
# d346e52092308430d6ec6faa668722219ce024db394c112...  Information - Magazine
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...  Information - Magazine
# ...                                                                    ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...  Information - Magazine
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...  Information - Magazine
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...  Information - Magazine
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...  Information - Magazine
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...  Information - Magazine
#
#                                                                   channel_program  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...                        Bonjour
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...                        Bonjour
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...                        Bonjour
# d346e52092308430d6ec6faa668722219ce024db394c112...                        Bonjour
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...                 Europe 1 Matin
# ...                                                                           ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...                 Le Grand Matin
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...           Mettez-vous d'accord
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...           Mettez-vous d'accord
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...           Mettez-vous d'accord
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...  Sud Radio dans tous ses états
#
#                                                                                                themes  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...  ["ressources", "changement_climatique_constat"...
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...  ["changement_climatique_constat", "biodiversit...
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...  ["attenuation_climatique_solutions", "biodiver...
# d346e52092308430d6ec6faa668722219ce024db394c112...  ["biodiversite_concepts_generaux", "attenuatio...
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...  ["biodiversite_concepts_generaux", "ressources...
# ...                                                                                               ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...  ["changement_climatique_constat", "changement_...
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...  ["biodiversite_concepts_generaux", "changement...
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...  ["changement_climatique_consequences", "biodiv...
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...  ["biodiversite_solutions", "biodiversite_conce...
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...  ["changement_climatique_constat_indirectes", "...
#
#                                                                                              keywords  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...  [{"keyword": "transition \u00e9cologique", "ti...
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...  [{"keyword": "ademe", "timestamp": 17040861260...
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...  [{"keyword": "sobri\u00e9t\u00e9", "timestamp"...
# d346e52092308430d6ec6faa668722219ce024db394c112...  [{"keyword": "emballage", "timestamp": 1704088...
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...  [{"keyword": "feux", "timestamp": 170408896200...
# ...                                                                                               ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...  [{"keyword": "agriculteur", "timestamp": 17224...
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...  [{"keyword": "eaux", "timestamp": 172241628202...
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...  [{"keyword": "alimentation", "timestamp": 1722...
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...  [{"keyword": "\u00e9coresponsable", "timestamp...
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...  [{"keyword": "quarante degr\u00e9s", "timestam...
#
#                                                     num_keywords  num_tokens  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...             1         524
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...             1         497
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...             1         496
# d346e52092308430d6ec6faa668722219ce024db394c112...             1         488
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...             1         528
# ...                                                          ...         ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...             4         530
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...             1         523
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...             2         566
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...             1         499
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...             3         532
#
#                                                     label_pred  prompt_tokens  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...  0_accepted           1424
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...  0_accepted           1392
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...  0_accepted           1397
# d346e52092308430d6ec6faa668722219ce024db394c112...  0_accepted           1385
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...  0_accepted           1422
# ...                                                        ...            ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...  0_accepted           1424
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...  0_accepted           1415
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...  0_accepted           1460
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...  0_accepted           1397
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...  0_accepted           1432
#
#                                                     completion_tokens  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...                 27
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...                 27
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...                 27
# d346e52092308430d6ec6faa668722219ce024db394c112...                 27
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...                 27
# ...                                                               ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...                 27
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...                 27
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...                 27
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...                 27
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...                 27
#
#                                                     total_tokens      cost  \
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...          1451  0.000230
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...          1419  0.000225
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...          1424  0.000226
# d346e52092308430d6ec6faa668722219ce024db394c112...          1412  0.000224
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...          1449  0.000229
# ...                                                          ...       ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...          1451  0.000230
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...          1442  0.000228
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...          1487  0.000235
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...          1424  0.000226
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...          1459  0.000231
#
#                                                    claim_pred
# id
# ae3110362b2d90e3b39022926052cb8c57d52be76f692df...        NaN
# 068edefaad4938b6cf7a86bf8e306f6968bbbf3c96e8462...        NaN
# f647d3fad5acbe70ee52b488bd3e8ec8be1018acc4e7756...        NaN
# d346e52092308430d6ec6faa668722219ce024db394c112...        NaN
# cb1c730c8eabec84989e98a517db234d22b495d3e0814a9...        NaN
# ...                                                       ...
# 32b48450801f677a3834cb84281b9d91d974f8c8d3ca7e8...        NaN
# 2750001e70a1cd4eae8ac6932a495b7ac97feeab1e9d747...        NaN
# 26b53013a4e78c907b56e884c01930963d66390e6d43146...        NaN
# 89f99c2aaec2f6c1c7b40b6bfb2d3054f8cec5fd9c67e69...        NaN
# 998581058446e17438c68bcf73997eb321c2de9be18afe8...        NaN
#
# [13760 rows x 16 columns]

# %%
# Generated code!
def approximate_match(text: str, claim: str, threshold=0.6) -> tuple[int, int] | None:
    # Preprocess text to remove casing and accents
    text = unidecode(text.lower())
    claim = claim.lower()

    # Split text and claim into words
    text_words = text.split()
    claim_words = claim.split()

    # Initialize variables to keep track of best match
    best_match_score = 0
    best_match_range = (None, None)

    # Slide a window of claim length over text to find the best match
    for i in range(len(text_words) - len(claim_words) + 1):
        # Extract a slice of words from the text to compare with claim
        window = text_words[i : i + len(claim_words)]

        # Calculate similarity ratio between the window and claim
        similarity = difflib.SequenceMatcher(None, window, claim_words).ratio()

        # Check if the similarity is above the threshold and better than the previous best
        if similarity > threshold and similarity > best_match_score:
            best_match_score = similarity
            best_match_range = (i, i + len(claim_words) - 1)

    # Convert word indices to character indices
    if best_match_range != (None, None):
        start_word_idx, end_word_idx = best_match_range
        start_char_idx = len(" ".join(text_words[:start_word_idx])) + (
            1 if start_word_idx > 0 else 0
        )
        end_char_idx = len(" ".join(text_words[: end_word_idx + 1]))
        return (start_char_idx, end_char_idx)
    else:
        return None

# %%
# Format for LabelStudio
# Only review flagged transcripts
data = []
for id, row in df[df["label_pred"] != "0_accepted"].iterrows():
    # Find the extracted claim in the original text
    text: str = row["text"]
    claim_pred: str = row["claim_pred"]
    try:
        # Try to see if we have a perfect match of claim in text
        start = text.lower().index(claim_pred.lower())
        end = start + len(claim_pred)
    except ValueError:
        # ValueError: substring not found
        matching_result = approximate_match(text, claim_pred, threshold=0.5)
        if matching_result:
            start, end = matching_result
        else:
            # The LLM "extracted" a claim that doesn't exist in the text...
            start, end = None, None

    # Pre-annotate the task with the model's prediction
    # We skip it if we couldn't match the extracted claim with the original text
    if start is not None:
        data.append(
            {
                "data": {
                    "id": id,
                    "start": str(row["start"]),
                    "text": text,
                    "channel_name": row["channel_name"],
                    "channel_program_type": row["channel_program_type"],
                    "channel_program": row["channel_program"],
                    "label_pred": row["label_pred"],
                    "claim_pred": claim_pred,
                },
                "predictions": [
                    {
                        "model_version": "claude-3-haiku",
                        "result": [
                            {
                                "value": {
                                    "start": start,
                                    "end": end,
                                    "text": text[start:end],
                                    "labels": [row["label_pred"]],
                                },
                                "from_name": "label",
                                "to_name": "text",
                                "type": "labels",
                            }
                        ],
                    }
                ],
            }
        )

# %%
# Save the LabelStudio tasks for import
with open(
    "../../data/experiments/label_studio_review/mediatree_predictions_07_2024_label_studio_review.json",
    "w",
) as f:
    json.dump(data, f)

# %%
len(data)
# Out:
# 202
