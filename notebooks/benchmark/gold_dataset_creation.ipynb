# %% [markdown]
# # Create a gold-standard dataset for evaluating classifiers
# As a first step, we'll extract a subset of interesting samples from MediaTree data.

# %%
import asyncio
import time

from openai import AsyncOpenAI
import pandas as pd
from pydantic import BaseModel, Field
import tiktoken
from tqdm.asyncio import tqdm

# %%
df = pd.read_parquet('../../data/18_channels_2023_09_to_2024_09.parquet')

# %%
df.groupby('channel_name').count()['start']
# Out:
# channel_name
# arte               1855
# bfmtv             16616
# d8                  251
# europe1            7792
# fr3-idf            4114
# france-culture     4803
# france-info       46489
# france-inter       9096
# france2            7065
# france24          19807
# itele             19107
# lci               11075
# m6                 3499
# rfi                7227
# rmc                7555
# rtl                7155
# sud-radio          7620
# tf1                4612
# Name: start, dtype: int64

# %%
SEED = 42
N_SAMPLES = 500
sample = df.sample(N_SAMPLES, random_state=SEED)
sample.groupby('channel_name').count()['start']
# Out:
# channel_name
# arte                6
# bfmtv              51
# d8                  1
# europe1            16
# fr3-idf             7
# france-culture      8
# france-info       120
# france-inter       19
# france2            17
# france24           58
# itele              52
# lci                37
# m6                  9
# rfi                24
# rmc                19
# rtl                15
# sud-radio          22
# tf1                19
# Name: start, dtype: int64

# %%
# we'll add back all the original c8/d8 samples because there are few of them and we know it's a suspicious channel
sample  = sample[sample.channel_name != 'd8']
sample = pd.concat((sample, df[df.channel_name == 'd8']))
print("Number of samples from C8:", sample.groupby('channel_name').count()['start']['d8'])
print('Total number of tokens:', sample.num_tokens.sum())
# Out:
# Number of samples from C8: 251
# Total number of tokens: 349715

# %%
# for now, we only want to surface interesting examples, i.e. containing a claim or something that looks like it (false positive)
# those examples will be labelled later on, either by hand or with a frontier model
# we know from previous tests that small models have a good recall, so we can use one for this task

client = AsyncOpenAI()
model = "gpt-4o-mini"
encoding = tiktoken.encoding_for_model(model)

prompt = """L'utilisateur va fournir un extrait de 2 minutes d'une émission de télévision ou de radio.
    Ce transcript ne contiendra pas de ponctuation mais ne sois pas dérangé par cela, le sens reste facilement compréhensible.

    Ta tâche est de prédire si cet extrait contient une allégation climatosceptique.
    En particulier, les allégations correspondant à l'une des catégories suivantes doivent être classées positives, c'est-à-dire comme contenant une allégation :
    1. Le réchauffement climatique n'est pas réél,
    2. Les gaz à effet de serre humains ne causent pas le réchauffement climatique,
    3. Les impacts du changement climatiques ne sont pas mauvais,
    4. Les solutions climatiques ne fonctionneront pas,
    5. Le mouvement/la science du climat n'est pas fiable.

    Réflechis-bien avant de répondre.
"""


class ClaimDetection(BaseModel):
    has_claim: bool = Field(description="Whether or not the extract contains a climate-skeptic claim.")


async def detect_claim(
    text: str, system_prompt: str = prompt, tpm_limit: int = 2e6
) -> ClaimDetection:
    prompt_tokens = len(encoding.encode(system_prompt))
    text_tokens = len(encoding.encode(text))
    total_tokens = prompt_tokens + text_tokens
    wait_time_s = 60 * total_tokens / tpm_limit
    await asyncio.sleep(wait_time_s)
    response = await client.beta.chat.completions.parse(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text},
        ],
        response_format=ClaimDetection,
        temperature=0,
    )
    detection = response.choices[0].message.parsed
    return detection


async def run_detections(texts: list[str]):
    semaphore = asyncio.Semaphore(10)
    
    async def bounded_detect_claim(text):
        async with semaphore:
            return await detect_claim(text)
    
    # Use tqdm_asyncio.gather with the bounded_detect_claim function
    predictions = await tqdm.gather(*[bounded_detect_claim(text) for text in texts])
    return predictions

# %%
predictions = await run_detections(sample["text"])
# Out:
#   0%|          | 0/750 [00:00<?, ?it/s]
# 100%|██████████| 750/750 [00:56<00:00, 13.19it/s]

# %%
sample['has_claim'] = [p.has_claim for p in predictions]

# %%
df
# Out:
#                                                                  start  \
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350... 2023-09-01 19:40:00
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b... 2023-09-01 19:42:00
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc... 2023-09-01 20:20:00
# d6b08b996cea24381de86c31a243122baa83bf750e03c91... 2023-09-01 20:44:00
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33... 2023-09-02 19:40:00
# ...                                                                ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b... 2024-08-31 13:08:00
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858... 2024-08-31 13:10:00
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef... 2024-08-31 19:58:00
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249... 2024-08-31 20:18:00
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8... 2024-08-31 20:34:00
#
#                                                                                                  text  \
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350...  choses le combat d' andré boma et du parc des ...
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b...  vient d' engager cinq milliards d' euros dans ...
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc...  parler une révolution par contre au niger euh ...
# d6b08b996cea24381de86c31a243122baa83bf750e03c91...  il faut rappeler le début de cette affaire c' ...
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33...  grandes plantations agricoles ont également mi...
# ...                                                                                               ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...  lui aussi par les moustiques touche une trenta...
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...  des griffes arracher la solution se trouve peu...
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...  albret <unk> madame monsieur bonsoir bienvenue...
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  modèles rechargeables séduisent les citadins i...
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  viticoles françaises la saison des vendanges a...
#
#                                                    channel_name  \
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350...         arte
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b...         arte
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc...         arte
# d6b08b996cea24381de86c31a243122baa83bf750e03c91...         arte
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33...         arte
# ...                                                         ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...          tf1
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...          tf1
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...          tf1
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...          tf1
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...          tf1
#
#                                                     channel_is_radio  \
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350...             False
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b...             False
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc...             False
# d6b08b996cea24381de86c31a243122baa83bf750e03c91...             False
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33...             False
# ...                                                              ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...             False
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...             False
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...             False
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...             False
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...             False
#
#                                                       channel_program_type  \
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350...   Information - Journal
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b...   Information - Journal
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc...  Information - Magazine
# d6b08b996cea24381de86c31a243122baa83bf750e03c91...  Information - Magazine
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33...   Information - Journal
# ...                                                                    ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...   Information - Journal
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...   Information - Journal
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...   Information - Journal
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...   Information - Journal
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...   Information - Journal
#
#                                                    channel_program  \
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350...              JT
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b...              JT
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc...      28 minutes
# d6b08b996cea24381de86c31a243122baa83bf750e03c91...      28 minutes
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33...              JT
# ...                                                            ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...          JT 13h
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...          JT 13h
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...  JT 20h + météo
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  JT 20h + météo
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  JT 20h + météo
#
#                                                                                                themes  \
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350...  ["biodiversite_concepts_generaux", "adaptation...
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b...  ["changement_climatique_causes", "attenuation_...
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc...  ["changement_climatique_causes", "changement_c...
# d6b08b996cea24381de86c31a243122baa83bf750e03c91...  ["biodiversite_concepts_generaux", "changement...
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33...  ["biodiversite_concepts_generaux", "biodiversi...
# ...                                                                                               ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...  ["biodiversite_consequences", "biodiversite_co...
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...  ["biodiversite_consequences", "attenuation_cli...
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...             ["changement_climatique_consequences"]
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  ["attenuation_climatique_solutions", "changeme...
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  ["attenuation_climatique_solutions", "changeme...
#
#                                                                                              keywords  \
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350...  [{"keyword": "\u00e9nergies fossiles", "timest...
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b...  [{"keyword": "\u00e9nergie renouvelable", "tim...
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc...  [{"keyword": "climatique", "timestamp": 169359...
# d6b08b996cea24381de86c31a243122baa83bf750e03c91...  [{"keyword": "vivant", "timestamp": 1693593844...
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33...  [{"keyword": "agricole", "timestamp": 16936763...
# ...                                                                                               ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...  [{"keyword": "renaturer", "timestamp": 1725102...
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...  [{"keyword": "agriculture", "timestamp": 17251...
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...  [{"keyword": "al\u00e9as climatiques", "timest...
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...  [{"keyword": "borne de recharge", "timestamp":...
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...  [{"keyword": "for\u00eat", "timestamp": 172512...
#
#                                                     num_keywords  num_tokens
# id
# 84e93fcd88fa86338651973326536d27d29f724a4864350...             3         448
# 21037a5700f15f8b1fb968dcf35c047bd0933816bc3f01b...             1         408
# a3aceee186595fab3603853ea38f3c51fe9453912a280cc...             1         647
# d6b08b996cea24381de86c31a243122baa83bf750e03c91...             1         537
# 391397ace2825ad3d4169797e37b685d1be499dd7ccea33...             6         443
# ...                                                          ...         ...
# 7e43ce79a3c9304277dde3a06b433d7cf08a9b40ee8904b...             4         474
# 4b5a990a668084eb50da9029b16f7f76ba44ffc89412858...             3         471
# d3ef252aaac62bdcd506e162d5454dfa346f9c75dbc74ef...             1         419
# c5fb91f75955000b6bc581b89a9ba6cc0efda7b47b0b249...             2         503
# ec42467d13f38ae9d625599a61d9acc71b4507c370525f8...             3         391
#
# [185738 rows x 10 columns]

# %%
df.channel_program_type.unique()
# Out:
# array(['Information - Journal', 'Information - Magazine',
#        'Information en continu', 'Information - Autres émissions'],
#       dtype=object)

# %%
sample[sample.has_claim].groupby('channel_program_type').count()
# Out:
#                         start  text  channel_name  channel_is_radio  \
# channel_program_type
# Information - Journal       6     6             6                 6
# Information - Magazine      3     3             3                 3
# Information en continu     12    12            12                12
#
#                         channel_program  themes  keywords  num_keywords  \
# channel_program_type
# Information - Journal                 6       6         6             6
# Information - Magazine                3       3         3             3
# Information en continu               12      12        12            12
#
#                         num_tokens  has_claim
# channel_program_type
# Information - Journal            6          6
# Information - Magazine           3          3
# Information en continu          12         12

# %%
import pprint
for t in sample[sample.has_claim].text:
    pprint.pp(t)
    print()
# Out:
# ("une telle pause m' a d' abord ça veut rien dire on a l' impression que la "
#  "phrase d' emmanuel macron c' est un peu vous savez comme camp de nicolas "
#  "sarkozy disait euh l' environnement ça commence à bien faire une pause ça "
#  "veut dire quoi d' abord il y a une production permanente de dispositions de "
#  'loi ne serait-ce que parce que notre système juridique est prévu comme ça '
#  'pour autoriser les industriels ont trouvées à venus conty de produire de la '
#  'valeur et font permanence produire de nouvelles réglementations donc cela '
#  "voudrait dire que dans ces réglementations nouvelle qu' on va créer à chaque "
#  'fois on ajoute pas de nouvelles normes alors à son là pourquoi pas macron '
#  'mais parle emmanuel à macron qui parle il à demande qui ce il qui est '
#  "demande demandé cinq aux acquis états membres mais dans ces cas là c' est la "
#  "voix de la france est à dire c' est lui-même directement par le biais de ses "
#  "ministres qui est euh à même d' exécuter cette décision il monte sa aux "
#  'députés mais lorsque la pourquoi est ce que les députés du groupe renew donc '
#  "les députés euh européen macronistes continuent eux mêmes d' ajouter une "
#  'nouvelle norme alors que le ppe par exemple a droite essaye depuis des mois '
#  "d' obtenir un moratoire sur les normes environnementales au parlement "
#  "européen donc on ne sait pas très bien à qui s' adresse et on en a le "
#  'sentiment si vous voulez que euh macron emmanuel est macron en est fait en '
#  'trente fait presque on de trempe parler presque à de lui-même en parler se '
#  "disant mais c' est vrai depuis six ans ça va pas il faudrait peut-être qu' "
#  'on se calme un petit peu sur les normes donc si je comprends bien vous '
#  "estimez qu' emmanuel macron n' est pas le mieux placé pour tenir ce discours "
#  "ben non seulement qu' on puisse dire alors je m' appuie sur une étude qui a "
#  "conduit l' ifrap qui montre que par exemple sur euh une norme "
#  "environnementale sur quatre la france sûr transpose le droit européen c' est "
#  "à dire que l' europe dit quelque chose et la france va dire encore plus euh "
#  "l' exemple par exemple c' est le glyphosate la france a imposé une "
#  "interdiction du glyphosate aux agriculteurs alors que l' europe continuent à "
#  'la maintenir bon et puis la france est championne aussi pour créer ses '
#  "propres normes un exemple parmi d' autres ce sont ces zones d' accélération "
#  "des énergies renouvelables auquel personne ne comprend rien en demande d' un "
#  'coup au maire de dire à quel endroit de sa ville il va pouvoir implanter ici '
#  'euh un mini panneaux feuilleté photovoltaïque etc donc il y a un effort part '
#  'atticus et de la france pour rajouter des tracas aux entrepreneurs aux élus '
#  "en matière d' écologie donc effectivement emmanuel macron peut être formulé "
#  "ce souhait à haute voix mais pour lui même il faudrait peut-être qu' il "
#  'arrête de rajouter des normes un peu partout pôle sud')
#
# ("paquebot du monde qui vient d' avoir lieu à miami bonjour bonjour qui <unk> "
#  'henri bonjour patrick bonjour à tous oui je reconnais la lorie votre volonté '
#  "d' adoucir les choses clairement je ne suis pas légèrement irritée je suis "
#  'révulsé écoeuré révolté et finalement accablé par le lancement de ce plus '
#  "grand paquebot du monde qui se nomme l' économie six qui a eu lieu samedi "
#  'dernier alors pour ceux qui ne pratique pas la langue of the seas à me dire '
#  "de la main mers le bateau s' appelle donc les comptes de un la monde mer "
#  "totalement totalement justifiée puisqu' il est il destiné est à destiné "
#  'offrir des croisières à une clientèle de connard de au niveau financier '
#  "parce que ça va quand même coûter une blinde connard parce qu' ils vont se "
#  "retrouver à dix m la dent du texan obèses de l' assureur du kentucky de la "
#  'veuve de fonds de pension à lunettes papillon dix milles qui vont se '
#  'retrouver sur <unk> cette merde flottant à devenir écarlate en passant leurs '
#  'journées sur le pont à regarder leur smartphone sans un regard sur les côtes '
#  'de bora-bora les comptes des mers mais attendez décrivent que le je monstre '
#  'décrive sept le piscines monstre six cette toboggans piscine neuf jacuzzis '
#  'une cascade de dix-sept mètres de haut quarante restaurants une succursale '
#  'du body love super finit par patrick roger lui-même je suis sûre que tu peux '
#  'même commander sur uber eats est un spin pizza qui depuis sa cabine et être '
#  'livré un travailleur précaire qui rejoint le bateau en pédalo qui vient de '
#  'donner de la pizza au bord de la piscine les piscines des bateaux les mecs '
#  "sont au milieu du pacifique dans des eaux turquoise au au lieu d' arrêt "
#  'arrêter leur putain de bateau de profiter de ces eaux il barbot dans une eau '
#  "essentiellement constitué d' eau de javel et deux pistes de texans et de "
#  "veuve de cincinnati c' est comment payer pour patiner sur une patinoire "
#  'artificielle installé sur un lac gelé mais sont malins les armateurs ils '
#  "disent qui sont sensibles à l' envi iron man la preuve c' est que le "
#  "paquebot n' utilise pas le fioul lourd comme d' habitude mais du méthane as "
#  "est bien mais c' est un puissant gaz à effet de serre c' est dommage là je "
#  "vous prie de m' excuser d' être un peu technique le metal dont le méthane")
#
# ("expliquons c' est que la raison pour laquelle on a gober ça c' est parce qu' "
#  'on a été bombardé de messages et pendant plus de cent ans ces industriels '
#  "américains on fait passer ses idées à travers des ouvrages d' enfants de la "
#  'littérature des films et à travers le monde universitaire ils nous ont fait '
#  "comprendre qu' il fallait qu' on fasse confiance à ce marché qui était "
#  "magique et qu' on avait absolument pas besoin avait de absolument l' pas "
#  "etat besoin pour de ne l' pas etat en pour face ne pas en face il y avait "
#  "pas d' idées concurrentes aussi forte woo ou alors de jambes si bien "
#  "organisée bien sûr qu' il avait une forme de concurrence et il y a beaucoup "
#  "de gens qui ont dit que c' était erronée ème édition que la partie adverse "
#  "n' était pas aussi puissants parce qu' elle avait moins d' argent ou pensées "
#  "par exemple aux syndicats aux etats-unis il disait que c' était faux tout ça "
#  "mais les syndicats n' avait ni de près ni de loin les mêmes moyens "
#  'financiers qui leur a permis de faire passer leurs leurs idées de idées la '
#  "de même manière la qu' même ont manière pourtant que pourtant nous en aurons "
#  "aussi on a gober ce mythe c' est tout à fait vrai alors bien pourquoi je "
#  'suis content que ledit soient traduits en français parce que même si ce '
#  "récit si vous voulez en premier lieu les etats-unis on parle des hommes d' "
#  "affaires américain il n' empêche que ses arguments se sont répandus aussi "
#  "dans le reste du monde et en europe c' est pour ça qu' on est heureux de "
#  "pouvoir public français aujourd' hui il aurait y pas aurait pas un "
#  'retournement en est-on revoit pas à travers des crises multiples '
#  "géopolitique climatiques sociales culturelles et ce qu' on voit un retour "
#  'des états qui remet un petit peu en place le rôle hégémonique des marchés je '
#  'pense que les choses sont en train de changer en effet justement le livre '
#  'arrive à point nommé à mon avis parce que les gens sont plus ouverts '
#  'actuellement sur cette idée sur le fait de repenser à la manière dont se '
#  'passent les choses voyez par exemple')
#
# ('danger il y a plein de petites choses mais il y a pas mal de choses et alors '
#  'le principal outil aussi ses cela végétaux végétalisation des zones des '
#  "zones urbaines c' est vrai que on a imperméabilité des sols à proximité des "
#  "cours d' eau y a un ruissellement qui est extrêmement important lâche parle "
#  'surtout sur les épisodes méditerranéens et euh ça ce sont des choses qui '
#  "aujourd' hui son corriger c' est vrai que les proxy la proximité des cours "
#  "d' eau quand on reconstruit on essaye de d' enlever tout ce qui est "
#  'imperméable et imperméable on et essaie on de faire essaie évacuer de '
#  "louhans faire en évacuer tout louhans cas en tout cas l' affaire s' "
#  'infiltrer alors pardonnez ma question de non initiés mais est-ce que ces '
#  'tempêtes sont liés au réchauffement climatique il faut toujours trouver un '
#  "responsable non mais c' est pourquoi j' ai toujours eu la chance ça a "
#  'toujours eu des tempêtes ia une étude qui a été menée par les services météo '
#  'la euh il y a quelque temps et qui étudie tous les phénomènes de tempêtes '
#  "depuis mille neuf cent quatre-vingts e on a pour l' instant sur euh donc "
#  "plus de quarante ans on n' a pas relevé de ce de qu' ce qu' on appelle "
#  "appelle ça un indice de sévérité des tempêtes et y a pas d' évolution "
#  "notable en tout cas il y a pas de consensus non il y en a pas plus pour l' "
#  'instant il y a aucun avis scientifique sur le sur le sujet les tempêtes il '
#  "n' y en a toujours eu on en a besoin euh vous savez c' est un peu le revers "
#  "de la monnaie a aussi on on est tout de même on sort d' une aussi période "
#  "alors tempête c' est un phénomène venteux venteux mais on a beaucoup plu "
#  'également ça on en parle pas trop un avec kieran mais on a des quantités qui '
#  "vont s' abattre quiberon est assez importante qui vont de l' ordre vont de "
#  "cinquante l' à ordre soixante litres de d' cinquante eau à en soixante six "
#  "heures litres d' eau en six heures donc ça c' est important mais le haut on "
#  "en a besoin on sort d' une sécheresse chronique depuis maintenant deux en "
#  "historiques cette pluie sincèrement elle est là la bienvenue et c' est le "
#  'rôle aussi de ce fameux rail de dépressions de ces phénomènes perturbée de '
#  'ces tempêtes éventuellement qui balaie et la france voilà quelque part cette '
#  "saison mais pour l' instant il y a aucun avis scientifique sur un lien avec "
#  "le dérèglement climatique sur un lien peut-être pas mais qu' elle pourrait "
#  "être la cause justement à l' avenir du réchauffement")
#
# ("fur et à mesure la sur le l' instant les orages concerne la région du puits "
#  "juste à l' est de lyon également un on a des orages assez forts lead "
#  'jaussaud du côté de bourgoin par exemple donc euh voila surtout ses taxes '
#  "allant de deux de du massif central les frontières de l' est les reliefs de "
#  "l' est et ensuite la la lorraine ce soir dans la nuit il faut être prudent "
#  'les orages peuvent être fort et pourquoi des orages aussi fort en raison des '
#  'températures parfois euh caniculaire est ce que ça a un lien oui absolument '
#  'mais vous avez raison et donc on avez a raison eu et beaucoup donc de on '
#  'chaleur a accumulée eu la beaucoup de depuis chaleur ses accumulée débuts la '
#  "depuis ces derniers jours sur tout le pays notamment dans le sud mais on l' "
#  "a vu il y a quelques heures encore dans le nord est également euh on a de l' "
#  "air froid qui arrive de l' atlantique qui vient au contact de cet air plus "
#  'chaud et dans toute cette zone de convergence de température tout au long de '
#  'cette ligne de où les températures baisseront contrastée euh des orages se '
#  'forme ça démarre dans les pyrénées et également dans la nuit et ça remonte '
#  "sur le nord-est tout cet axe sud-ouest nord-est ski au contact de l' air "
#  "chaud et de l' air plus froid qui arrive de l' question atlantique dernière "
#  'est question ce est ce que cette situation va perdurer ces prochains jours '
#  'et oui malheureusement on a on a une persistance de deux un temps instable '
#  'la dont les modèles de météo france nos collègues prévisionnistes continuent '
#  'de voir des choses se former encore demain plutôt côté sud sud-est paca peut '
#  'être et rhône alpes et puis encore toujours euh pour la journée de jeudi le '
#  "vendredi de l' instabilité qui demeure dans le sud de la france "
#  'particulièrement donc voilà il faut garder les elle allait la prévision de '
#  'suivre les prévisions de près et les écouter bonnes les consignes bonnes '
#  "consignes qui selon sont un communiqués communiqué l' entendre toutes les "
#  'régions qui sont concernés notamment par la vigilance orange guillaume ferry '
#  'directeur de la surveillance de la filiale risques de météo france predict '
#  'en montagne ou les orages en sont parfois aussi virulents et les refuges les '
#  'remontées méka yannick peuvent être menacés par le réchauffement climatique '
#  'la déstabilisation du permafrost et la fonte des glaciers fragilise en effet '
#  "les structures et c' est le cas dans les alpes ou certains bâtiments")
#
# ('précipitation donc cette décrue tant attendue va encore attendre quelques '
#  "quelques heures voire quelques jours et ce n' est qu' à partir de deux ce "
#  "week end qu' on a un changement radical de temps avec un gars du nord qui va "
#  'descendre plus du nord plus froid mais plus sec on pourrait on pourrait '
#  'espérer que la décrue elle se met en uvre à partir de ce week end la semaine '
#  'prochaine est ce que ces précipitations sont exceptionnelles pour la saison '
#  'elles sont exceptionnelles et sont son exceptionnelles exceptionnelle de la '
#  'durée on a déjà eu des crues quasiment similaire début novembre puis de '
#  'nouveau en décembre et en un cumul de précipitations sur les deux mois qui '
#  'approche les cinq millimètres qui est vraiment exceptionnel et autant de de '
#  "crue sur le pas-de-calais avec cette fréquence c' est un phénomène qui n' a "
#  "jamais été c' est ce que le réchauffement climatique est en partie "
#  "responsable de la situation ça c' est complexe une rond situation là "
#  'complexe on a et on un le euros dit et redit ces précipitations ces '
#  "inondations le pas-de-calais sont liés à ce à ce passage d' une succession "
#  "de tempêtes qu' ait connue le nord de la france depuis la chaîne de l' "
#  "automne et l' hiver on se rappelle le cas de symptômes peut se seraient des "
#  'tempêtes les études scientifiques on ne montre pas de corrélation entre le '
#  'la fréquence de ces tempêtes et le réchauffement climatique par contre ce '
#  "que l' on sait c' est que dès que on a un degré de plus dans l' atmosphère y "
#  "a plus de vingt y heures a donc plus c' de est possible vingt et heures donc "
#  'de des wauquiez internes possible dans des intensités de pluie et des cumuls '
#  "de précipitations qui semble plus important c' est donc comme on le sait l' "
#  "année deux mille vingt-trois a été l' année la plus chaude jamais mesurée à "
#  "l' océan atlantique était particulièrement chaud la mâche aussi des facteurs "
#  "qui sont devenus un maître de la vapeur d' eau augmenter le carbet grande "
#  'vedette de cette tempête et donc de cette partie là effectivement on peut '
#  "être pensé que le dérèglement climatique et à et à l' origine du cumul des "
#  "précipitations et que donc ce que l' heureux dr")
#
# ('sur le réchauffement climatique mais dans le même temps ben arrivent au '
#  'pouvoir dans de nombreux pays des gens des personnalités comme lui javier '
#  'milei élu à la présidence en argentine puis il y a aussi euh geert wilders '
#  "qui a gagné les élections aux pays bas qu' on va voir ben on sent bien que "
#  "pour ses leaders ont tout cas le climat c' est vraiment le cadet de leurs "
#  'soucis regarder ils ont remporté une élection ces dernières semaines parmi '
#  'leurs points communs il y a leur leur discours sur le le réchauffement '
#  'climatique un climat devrions pas dépenser vingt-huit milliards pour le '
#  'climat sans aucun effort investissez intelligemment dans une adaptation '
#  'climatique moins couteux des responsables importants ainsi son ennui '
#  'walkenburg je ne nie pas le changement climatique quelque chose que je dis '
#  "qu' est ce qu' il existe un cycle de température dans l' histoire de la "
#  'terre autrement dit il existe un comportement cyclo cycle dont toutes ces '
#  "politiques qui accusent les humains d' être responsables du changement sont "
#  "climatique sont faux fausses sang en face à l' argentin javier argentin "
#  'javier milei le néerlandais geert wilders ont fait campagne en promouvant '
#  'des discours climatosceptiques contre le consensus scientifique sur son '
#  'manifeste électoral le parti de geert wilders tenait un discours encore plus '
#  'radical de minimisation du réchauffement climatique nous avons peur du '
#  "changement thématiques depuis des décennies il faut arrêter d' avoir peur "
#  'les pays bas sont un pays intelligent nous disposons des meilleurs '
#  'ingénieurs hydrauliques au monde des ingénieurs pour contrer le le '
#  'réchauffement planétaire et la et montée la montée des eaux et une '
#  'rhétorique classique des nouvelles formes de climatoscepticisme selon les '
#  'chercheurs spécialistes des discours sur le climat servait de minimiser '
#  "plutôt finalement l' importance de ce qui se passe bien les causes et donc "
#  "plus que le climatoscepticisme à proprement parler on va voir l' émergence "
#  "en parallèle de sa de discours comme le technosolutionnisme c' est-à-dire le "
#  'fait de dire ben il suffira de trouver des bonnes inventions technologiques '
#  "et naturels sur les bons boutons climatique ça c' est aussi un discours qui "
#  'ont le vent')
#
# ("les personnes âgées mais le plus important c' est c' est d' abord la "
#  'responsabilité individuelle de chacun on a évoqué la canicule de deux mille '
#  "trois à l' époque on a découvert avec stupéfaction que des centaines voire "
#  'des milliers de nos aînés avaient été prises pour certains abandonnés par '
#  'leurs familles et étaient décédés toutes seules chez eux donc il ne il me '
#  "paraît évident et naturel que nous soyons d' abord les premières "
#  'responsables de nos parents de nos grands-parents et de prendre soin dans '
#  'les dans les semaines qui viennent alors que alors les que températures les '
#  "vont températures monter vont voilà de monter les contacter deux de s' "
#  "assurer qu' elles ont bien plus leurs responsabilités en effet sociétal mais "
#  'aussi euh intra générationnel il faut le dire à un but au passage mettre '
#  "même quand même il y a quelque chose d' inquiétant de la part du ministre de "
#  "la santé puisque nous dit quand aurait été incapable de déterminer s' il y "
#  "avait une canicule entraînerait des conséquences un manque d' anticipation "
#  "quand même ce qui m' inquiète c' est que malgré la crise que l' on a connu "
#  "nolot n' ont pas provoqué d' affût à l' hôpital et heureusement heureusement "
#  'mais demain si demain cela si venait cela à venait se à reproduire se les '
#  "reproduire euh justement les enseignements que l' on a pris sur les alertes "
#  'des services des urgences ont justement alerté au plan canicule prennent les '
#  "mesures qui s' impose on n' a pas de n' a pas beaucoup d' informations à "
#  "chaque fois écoutés je vais reprendre l' expression que vous vouliez me "
#  "prêter de l' heure en été il fait chaud faut écouter on est repartis écouter "
#  "ça va ça va durer deux jours trois jours voire on va s' adapter maintenant "
#  'il y a un numéro vert il il pleut un pleut numéro un vert numéro inhesj vert '
#  'un numéro vert il fait chaud un numéro vert là non ça va on est en été il '
#  "fait chaud ben oui il fait chaud le réchauffement climatique c' est quand "
#  "même pas une non mais non d' éminents scientifiques non mais là on n' est "
#  "pas on est on est pas dans un cas où sandrine degrés la pole pour l' instant "
#  'tout va bien le but visé en fait les peines à jouir du sanitairement est '
#  "correcte un pseudo ces gens qui nous raconte que ses bêtes l' apocalypse")
#
# ('un homme de trente ans hier en seine-saint-denis quelques heures après son '
#  'interpellation à montfermeil les policiers ont utilisé leur taser a une '
#  "dizaine de reprises pour le maîtriser l' igpn doit dire si l' usage de ses "
#  'pistolet à impulsion électrique était donc justifiée et proportionnée '
#  'interdiction de pêcher ou de vente dr les coquillages de bouin en vendée '
#  "mais aussi les huîtres du lac d' hossegor dans les landes comme dans d' "
#  'autres régions du bord de mer ils sont contaminés au neuro virus de '
#  'responsable toxiques de infections toxiques alimentaires infections à '
#  "alimentaires savoir à des savoir symptômes des similaires à ceux d' une "
#  "gastro entérite aiguë infos signé valentine l' hôtesse on en vient à ces "
#  "manifestations anti jo organisé aujourd' hui pas contre les jeux de l' été "
#  'prochain mais contre ceux qui se profile dans les alpes en deux mille trente '
#  "jo d' hiver les régions auvergne rhône alpes et paca son présélectionné par "
#  "le cio il reste plusieurs mois d' évaluation avant une décision finale qui "
#  "est attendu relativement rapidement dans les prochains mois mais l' "
#  "opposition commence quand même à s' organiser dans les alpes alors que alors "
#  'le que manque le de manque neige de est neige déjà est une réalité déjà '
#  'reportage une réalité reportage mathilde lamberti ces jo sont un contrepied '
#  'à tous les efforts de transition argumente en premier lieu freddy maignan '
#  'association mountain wilderness et les gardiens de refuge dans le massif de '
#  "belledonne près de grenoble ce recul de l' année le recul des glaciers ce "
#  "recul de l' eau tout simplement est quelque chose qui crée une cité façon "
#  'totalement nouvelle orleans on nous ressort un truc comme on la sent mille '
#  'neuf cent soixante-huit ou en mille neuf cent vingt-quatre e en deux mille '
#  'trente on va faire rêver les enfants de la montagne sur des belles images de '
#  "ce qui est sur toujours un ciel d' azur et tout ça est au même moment on "
#  "aura la moitié des stations qui seront soit en faillite soit en train d' "
#  "être fermé on se raccroche aux branches du passé donc effectivement c' est "
#  "rassurant mais on se rassure avec quelque chose qui se cache l' aïeul les "
#  'présidents de région paca et auvergne rhône alpes renaud muselier laurent '
#  "wauquiez parle de <unk> un projet sobre avec l' utilisation de sites "
#  "existence des jo d' albertville notamment c' est de l' affichage pour les "
#  "montagnards les plus sceptiques il y aura des investissements et beaucoup d' "
#  'émissions de co deux déplore notamment valérie paumier')
#
# ("car ce jour-là au plus fort de la canicule treize pourcent de l' europe "
#  'était confronté à ce stress thermique du jamais vu la chaleur extrême a '
#  "frappé surtout le sud de l' europe où la température de l' air a atteint "
#  "jusqu' à quarante huit degrés virgule deux en sicile un rapport qui précise "
#  'que les trois années les pins plus chaude jamais mesurée en europe ont eu '
#  "lieu après deux mille vingt alors oui il fait froid actuellement mais ça c' "
#  "est la météo un c' est pas l' évolution du climat pour l' avenir investissez "
#  'plutôt sur est les plutôt salades sur que les des salades raclettes que je '
#  "des sais raclettes c' je est sais dur c' est dur mais la fin de la raquette "
#  "c' est aussi une des conséquences du réchauffement climatique à l' est la "
#  "suite du dix-neuf vingt et un site avec vingt-huit minutes et l' essentiel "
#  "du dessous des cartes et pour l' heure c' est arte journal et nous on se "
#  "retrouve juste <unk> après aujourd' hui cinéma sur arte vingt heures "
#  "cinquante cinq la guerre des gangs fait rage à new-york un chef-d' oeuvre de "
#  'dicaprio scorsese avec dicaprio vingt-trois heures quarante un américain '
#  "enquête sur l' implication nazis du chef d' orchestre wilhelm furtwaengler "
#  'keysight sur la plateforme arte point tv la sémillante avocate anna conti '
#  "enquêtent sur un père de famille après le braquage raté d' une banque <unk> "
#  "les idées elles peuvent naître peuvent partout naître à partout n' importe "
#  "quel endroit que ce soit celle qu' on a petit celle qui nous fait grandir "
#  'celle qui peut changer la vie alors pour vous donner toutes les chances de '
#  'faire grandir vos idées nous avons créé sg une grande banque plus réactive '
#  'et plus expert au plus près de vous et ça fait toute la différence sg <unk> '
#  '<unk>')
#
# ('quelques mois dans les cellules de la dst ou en prendra leur empreinte '
#  'digitale de manière très gentil donc comme président fondateur lutte contre '
#  "l' opposition godoy nsb il lutte contre le réchauffement climatique un beau "
#  "leader écologique qu' il est tout ceci s' ajoute aux fait déjà que s' "
#  'opposer au troisième mandat de président fondateur est en bonne place sur la '
#  'liste des menaces à la sécurité nationale finalement mon cher condamné le '
#  'seul moment où la vie père quotidienne by coïncide quotidien avec coïncide '
#  "l' avec agenda l' de agenda de la côte cop c' est quand brusquement "
#  'inexplicablement papeete chauffe transpire tout le temps le matin à midi la '
#  "nuit à la maison d' un ta voiture au travail partout mais ce n' est pas le "
#  'réchauffement climatique et on compte en banque qui a fondu comme du beurre '
#  'sur le feu dès le début du mois sous le souffle chaud des prix de la viande '
#  "du rides l' huile du sucre de la farine qui ne font que monter tous les "
#  "jours morale de l' histoire quand ça chauffe ce n' est pas forcément le ça "
#  'réchauffement y climatique mais contribue ça grandement y à contribue '
#  'grandement demain merci maman et à demain un nouveau journal dans une minute '
#  "bonjour c' est juan gomez abidjan la plus grande ville de côte d' ivoire "
#  "vient d' interdire la mendicité et le commerce ambulant sur les grandes "
#  'artères les autorités veulent ainsi lutter contre le désordre urbain que '
#  "pensez-vous de cette mesure est-il possible d' éradiquer ces phénomènes on "
#  "en parle appels sur l' actualité trente-trois neuf six cent quinze vingt "
#  'treize six cent quatre-vingt treize soixante-dix retrouver appels sur font '
#  "l' actualité à banque bangkok atlantique à partir de huit heures dix tu as "
#  "tout à l' heure sur rfi c' est pas du vent anne cécile bras vous donne "
#  'désormais rendez-vous tous les mercredis pour le club cepa devant avec les '
#  "journalistes de rfi et d' autres médias qui reviendront cette semaine sur "
#  'les sujets environnementaux qui les ont marqués ils partageront avec vous '
#  'les coulisses de leur travail et comme entrant les films produits par les '
#  "vidéastes du réseau c' est pas du vent anne cécile bras du mercredi au "
#  'vendredi à paris')
#
# ("fais un communiqué sur radio gandois nat et ils disent que c' est de la "
#  "propagande sait si les attrape cela et yvon voit excellence c' est pour ça "
#  "qu' aujourd' hui un très très démocratique république certain ont inventé la "
#  "propagande positive c' est à dire qu' on ajoute une couche supplémentaire à "
#  'la mode <unk> épilation si la propagande de la manipulation et battre on '
#  "passe à la manipulation positives à un gros le soda n' est pas bon pour la "
#  "santé mais ça main mange je boit bois du coca zéro la propagande positive c' "
#  'est la vérité alternative avec filtres snapchat les groupes armés attaquent '
#  "partout dans le pays la propagande positif dit que l' armée monte en "
#  'puissance les gens prennent leur baluchon pour fuir leur village est bien la '
#  "propagande positive dit que le tourisme est en plein boom c' est ça la "
#  "propagande positive dit du bien de ton pays mon ami non dit du bien de l' "
#  'action de ton gouvernement legault doina la fièvre bécasse le thermomètre '
#  "est le dit thermomètre que est c' dit est le que réchauffement si climatique "
#  'le réchauffement climatique ta compris aller à demain demain mahamane et '
#  "merci bonjour c' est juan gomez au sénégal alors qu' une loi d' amnistie a "
#  'été adopté à la fin du mandat de macky sall un collectif des victimes des '
#  'manifestations de ces trois dernières années réclament justice et demande un '
#  "mandat d' arrêt international contre l' ancien président que vous inspire "
#  "cette initiative a-t-elle sur l' actualité trente-trois neuf six cents kg "
#  'quatre vingt treize six cent quatre-vingt retrouver treize appels '
#  "soixante-dix sur retrouver l' appels actualité sur avec l' banque actualité "
#  "atlantique à partir de huit heures dix tu as tout à l' heure sur rfi huit "
#  'milliards de voisins emmanuel bastide attend vos témoignages sur les thèmes '
#  "de cette semaine aujourd' hui entreprendre en afrique avec les conseils du "
#  'coach didier acuité demain comment se reconstruisent les survivantes yézidis '
#  "après le massacre de leur communauté par l' organisation etat islamique "
#  'contactez nous sur notre numéro whatsapp trente-trois sept soixante cac '
#  'quarante cinq cinquante et un quarante et un huit milliards')
#
# ('donc vous allez la répercuter encore on va répercuter sur le coût bien sûr '
#  "on ne peut pas faire autrement c' est pas possible écoutez merci mille fois "
#  "olivier reeves d' avoir accepté de témoigner c' est pas assez passable ces "
#  'courageux aussi la mesure où effectivement euh on parle de la hausse des '
#  'prix chez les garagistes et merci pour votre témoignage petites réactions '
#  "euh boys david dernières réactions sur le sujet la hausse des prix de l' "
#  "électricité c' est absolument extraordinaire l' allemagne il a choisi choisi "
#  'de sortir du nucléaire du pour nucléaire travailler pour sur travailler '
#  'surtout pour faire plaisir aux écologistes et pour travailler avec le gaz '
#  "notamment le gaz russe c' était avant la guerre en ukraine c' est tellement "
#  "un succès déjà qu' ils ont dit à la france et ils ont imposé le marché "
#  "européen d' électricité et au nom du couple franco-allemand on a évidemment "
#  "dit oui le couple franco-allemand qui n' existe que dans la tête des élites "
#  'françaises mais absolument pas en allemagne et le couple franco-allemand si '
#  'je devais la résumer de manière un peu triviales la france et la femme qui '
#  "et est battu trompé sec et mais battu donc le problème c' est est que qu' le "
#  'on problème est contents de cet état de fait donc on paye je vous parlais '
#  "des usines sidérurgiques et quelques minutes vous voyez les boulangers l' "
#  "usine sidérurgique c' est un peu abstrait ainsi l' usine qui fait des pieds "
#  "de des rouleaux d' acier pour l' usine automobile etc boulanger y en a "
#  "beaucoup qui ont mis la clé sous la porte faut quand même le et rappeler d' "
#  'autres qui ont mis la clé sous la porte pourquoi au nom du dogme du couple '
#  "franco-allemand parce que les allemands l' ont imposé pour ne pas qu' avec "
#  'le nucléaire la france est un avantage par compétitif rapport par à rapport '
#  "l' à industrie l' allemande industrie je allemande termine je sur termine un "
#  "mot la sortie du nucléaire en allemagne c' est absolument fabuleux puisque "
#  'maintenant il rouvre même plus des centrales au charbon mais des centrales à '
#  'lignite qui est encore plus polluant que chaque belge que le charbon line '
#  'deux qui vont rouvrir je crois que dans le land du mecklembourg-poméranie '
#  "extraordinaire pour l' environnement un mot sur cette hausse de dix pourcent "
#  "annoncé ce je matin n' ai même pas c' est pas acceptable voilà on était les "
#  'rois du monde on était on avait une souveraineté souveraineté énergétique '
#  'maintenant se retrouvent dépendant de quelque chose conakry')
#
# ("sur les routes de drôme de remorques et vous avez voté contre d' ailleurs à "
#  'contre courant votre partie en deux mots pourquoi euh en fait les partis '
#  "politiques européens ont été très divisé sur ce sujet parce que c' était "
#  "plutôt une question nationale une question de choix nationale qu' une "
#  'question de couleur politique nous nous avons voté contre la création de '
#  "<unk> ces méga camions l' installation de ces méga camions sur la route c' "
#  "est une aberration aujourd' hui notre défi comment oui mais tu vois la place "
#  'des européens qui ont dit vous avez droit à cent pour cent de voitures '
#  "électriques vous n' avez pas n' le avez choix pas de vous le vous choix êtes "
#  "de obligé vous d' vous abandonner êtes votre obligé voiture d' abandonner "
#  'votre voiture thermique nous on va faire rouler des méga camions sur vos '
#  "routes c' est une folie des plus gros camions mais ils y seront moins "
#  "nombreux aujourd' hui la vraie solution pour le transport logistique c' est "
#  "le ferait il faut investir sur le train et on a la chance d' avoir un réseau "
#  'ferroviaire exceptionnel mais il est très largement sous utilisées sur ce '
#  "sujet n' est fait concrètement on subventionne en réalité le transport par "
#  "camions si on vous parliez tout à l' heure de <unk> des problèmes avec la "
#  'voiture propre effectivement la batterie électrique si je batterie ne '
#  "électrique l' si étions je mais ne sans l' lithium étions il mais y sans a "
#  'lithium pas il de y patrie a pas de batteries électriques il y a pas de '
#  "voiture propre et on l' appelle le pétrole de vingt et unième siècle le "
#  "pétrole s' en est parce que ça provoque aussi des catastrophes écologiques "
#  "la rouille et d' exploiter euh et l' empreinte carbone est très très lourdes "
#  'et la question tu es sûr que ce paradoxe est ce que vous en aviez touché un '
#  "mot et ce qu' au parlement européen ska il cocommissaire y a une réflexion "
#  "sur ceci ce paradoxe l' empreinte carbone des transports en europe va "
#  'baisser avec cette voiture dit propre mais de carbone produit pour y '
#  'parvenir va augmenter que ce soit en europe au dans le reste du monde et eau '
#  "ce dans qui le a reste une du réflexion monde à et ce s' qui il est y un a "
#  "chiffre une réflexion à ce qu' un chiffrage d' ailleurs de ce paradoxe en "
#  "fait le paradoxe vous l' avez très bien exprimé c' est que on baisse nos "
#  "émissions de carbone mais on augmente notre empreinte parce qu' on laisse d' "
#  "autres pays extra européens sérieux mais en ce qu' on s' y intéresse sauf "
#  "qu' on tient compte ça sur tous les autres secteurs oui bien sûr alors sur "
#  'le sujet des terrains maria anciaux il y a un travail très intéressant qui a '
#  'été menée on a construit un rapport sur les matières premières critiques '
#  'avec des groupes dont le parti maintenant vous identifiez la dépendance de '
#  "l' europe à l' égard de ces matières premières critiques vous parliez")
#
# ("a hyper plus haut degré c' est quand même quelque chose d' assez terrible le "
#  'climatosceptique qui devient climato réaliste et ce que ça me semble '
#  "cohérent aujourd' hui dans le climat tout réalisme consiste os consistent "
#  "quelquefois dire on trouvera une solution et ça s' est joué au jeu je crois "
#  "que c' est ça l' erreur l' erreur c' est que beaucoup de gens pensent qu' on "
#  'trouvera des solutions technologiques alors la technologie peut être utile '
#  'pour lutter contre le réchauffement climatique mais simplement elle peut y '
#  "contribuer ce n' ce est pas n' disons est il faut pas aussi un disons "
#  'changement il de mode faut aussi un changement de mode de fonctionnement de '
#  'nos sociétés donc est réaliste effectivement disons patrick pouyanné en '
#  "disant nous vous moi nous utilisons toujours du pétrole du gaz c' est vrai "
#  'mais justement il faut absolument euh quitter ceux des intoxiqué des '
#  "combustibles fossiles la neutralité carbone c' est en pratique quasiment "
#  'abandonné ses combustibles justement je suis sûr que vous avez lu cette '
#  'tribune signée par patrick pouyanné entre autres euh dimanche dimanche euh '
#  'une tribune pour réclamer écrire une accélération de la transition '
#  'écologique vous dit quoi ce fond là ou alors quelle bande hypocrite oui là '
#  "c' est un peu hypocrite parce que bon d' un côté il y en ait dit clairement "
#  "vallée lentement de l' eau tu demandes une accélération oui il faut "
#  'accélérer il a raison donc je préfère ce cette tribu guns à dison à son '
#  'intervention lors de la journée du medef mais bon on voit bien on voit bien '
#  "la difficulté de son avancée c' est vraiment on est vigilants oui et puis ce "
#  'et sont puis les ce combustibles sont fossiles les qui combustibles sont '
#  "fossiles au qui cur sont du au cur du problème c' est très clair il ne faut "
#  "pas toujours mettre le problème sur d' autres difficultés qu' on nous "
#  "aujourd' hui on va s' intéresser aux climato scepticisme et signe le retour "
#  "sous quelle forme camille bonjour vous allez nous parler d' un "
#  'climatosceptique particulièrement médiatique et que vous connaissez bien '
#  "jean jouzel il s' appelle claude allègre alors vous géraldine vous allez "
#  'vous pencher sur le langage des journalistes les journalistes exactement '
#  "comment ils sont passés du conditionnel à l' indicatif pourquoi pas aujourd' "
#  "hui l' impératif d' une petite leçon de grammaire en fin d' émission voilà "
#  'les')
#
# ('plus ok mais concrètement comment ça se fait il faut que nos groupes euh nos '
#  'groupes français investissent en france il y a eue emmanuel macron et bruno '
#  "le maire chaque fois dix regardez c' est fabuleux euh les groupes étrangers "
#  "investissent en france il oublie chaque fois de donner l' eau chiffres c' "
#  "est-à-dire que les groupes français investissent deux fois plus à l' "
#  'étranger donc redonner envie et je pense que le groupe au groupe français on '
#  "en a un hui impératif stellantis aujourd' aujour hu d' stellantis hui "
#  "aujourd' parce hui que vous connaissez mieux que nous stellantis jean-pierre "
#  "mercier e jacomet d' usines en france que ça représente la fabrication en "
#  "france chez stellantis et la fabrication à l' étranger presque une "
#  "relocalisation ou aujourd' hui en france c' est quoi c' est peut être sept "
#  'cent huit cent mille véhicules qui sont produits en france euh évidemment '
#  'que ça ça a abaissé sa ça a chuté sa chute carlos tavares prend prétexte '
#  "comme tous les patrons de l' automobile d' ailleurs euh du monde entier de "
#  'la fameuse la transition fameuse énergétique le transition passage '
#  "énergétique à l' électrique pour euh pour fermer les usines pour euh "
#  'licencié à tour de bras et des usines stellantis ont fermé en france et des '
#  'licenciements oui il y en a une euh à douvrin dans le nord de la france qui '
#  "fabrique des moteurs thermiques qui on passe d' être fermé une deuxième l' "
#  'usine de messe de bouilly qui fabrique des boîtes de vitesses qui on passe '
#  "d' être fermé il y a sûrement être ouvertes avec la transition parce que je "
#  'vois je me suis dit et je je vais vous répondre oui répondre douvrin oui '
#  "moto douvrin motte fabrication de moteurs thermiques s' était allé mille "
#  'cinq cent mille deux mille salariés il y a une usine à cesser donc de '
#  "fabrication de batteries de batterie hyper subventionnées par l' europe euh "
#  "le confort et l' etat français cinq cents cinq cents salariés fait la "
#  'différence vous faites le delta on est on crève de cette euh de de cette '
#  'transition énergétique en plus on sait même pas si au bout du compte au '
#  'niveau de la technologie ça va marcher')
#
# ("giec et ce que ce que dit le rapport du giec sur ces questions donc j' ai "
#  'une certaine compte alors quelque chose quelque dix le rapport du giec sur '
#  "ces questions c' est que ça fait partie de la climatisation on fait partie "
#  "des mesures d' adaptation au changement climatique le rapport du giec "
#  "utilise le mot cible et c' est à dire il recommande une climatisation cibler "
#  'quel que soit notre ou leur dire ça vous devez ça veut dire que si vous avez '
#  "un logement que vous avez besoin quand même d' avoir au d' moment avoir de "
#  "au vous moment reposer lorsqu' de il vous fait reposer extrêmement lorsqu' "
#  'il fait extrêmement chaud vous pouvez avoir eu une pièce une pièce qui est '
#  "correctement isolé dans quel but oui mais peut-être pas besoin de voir l' "
#  "ensemble des gens qui qui est climatisée parce qu' effectivement que la "
#  "problématique c' est celle de l' énergie il est tout ça nécessite de l' "
#  "énergie et donc plus de cut fédère plus de consommation alors l' équipe "
#  "électrique de est l' peu énergie dire électrique que c' que est c' est avec "
#  "l' électricité concourront au concours donc ça fait la promo dont nous coûte "
#  "ça te tombe sur la problématique comment est-ce qu' on produit notre "
#  "électricité et de combats boit suffisamment d' électricité et la production "
#  "d' électricité conduit à mettre des gaz à effet de serre dans l' atmosphère "
#  "on retombe dans l' ensemble finalement l' intégralité de la limitation du "
#  "changement climatique et on a besoin on va avoir a besoin on va d' avoir "
#  "besoin énergie d' on énergie on peut essayer de limiter les consommations d' "
#  "énergie de groupe en avoir besoin et donc il faut avoir de l' électricité "
#  'peut carbone et donc il faut développer les énergies renouvelables et il '
#  "faut développer le nucléaire je pense que ces affections il n' y alla pas "
#  'par contre je pense que je trouve effectivement assez ridicule cette idée de '
#  "gloire l' interdire pourquoi est ce qu' on accepte que les gens se chauffent "
#  "au niger et pourquoi est ce qu' on interdirait qu' ils utilisent hakim en "
#  'été il y a pas de raison objective ça parce que ça peut sauver des vies')
#
# ("france mise sur le nucléaire pour leur avenir énergétique est bien ce n' est "
#  "pas le cas de l' autriche qui reste fermement opposés à l' atome depuis "
#  "longtemps c' est assez historique mais sans pour autant s' accrocher aux "
#  "énergies fossiles et d' ailleurs un drôle de bâtiments symbolise cela la "
#  'centrale nucléaire de ce fait elle ne dort fait unique au monde construit en '
#  'mille neuf cent soixante-seize elle ne fut jamais mis en service car les '
#  'autrichiens ont dit non à la tomme deux ans plus tard par référendum elle '
#  'est depuis restée figée dans ces époques alès un thème thèmes phare phares à '
#  "regarder ses couleurs ses c' est couleurs typique des années soixante-dix il "
#  "y a beaucoup d' orange du vert vif de nombreux visiteurs retrouve ici un peu "
#  "de leur jeunesse stéphane tsar de l' entreprise propriétaire de la centrale "
#  'la fait visiter à quinze mille personnes chaque année outre le réacteur ils '
#  'peuvent voir la salle de contrôle ou encore la chambre de condensation on a '
#  "l' écho incroyable la centrale accueille également des tournages de films de "
#  "clip mais elle a aujourd' hui d' autres missions tourné vers l' avenir trois "
#  'étaient streets two of his mother earth mother est in de the plus end en of '
#  "plus est de plus en plus utilisés comme centres d' entraînement au "
#  'démantèlement qui y exercent y on voit comment démantelé au mieux et sans '
#  'danger les centrales nucléaires après leur fermeture à pain que nous avons '
#  'construit une grande installation photovoltaïque sur zone on fait donc '
#  "également devenu un symbole de l' avenir des énergies renouvelables voir "
#  "plus de quatre vingt cinq pour cent de l' électricité autrichienne est "
#  "produite à partir d' énergies renouvelables et le gouvernement et que le "
#  "conservateur souhaite atteindre cent pour cent d' ici deux mille trente "
#  "viennent visent aussi la neutralité neutralité carbone d' ici ici deux mille "
#  "deux quarante mille quarante soit dix ans avant l' union européenne le tout "
#  "sans nucléaire un modèle que la ministre de l' environnement léonor reguev "
#  'haessler entend défendre sur la scène européenne dessine et même à créer et '
#  "nous sommes dans une décennie critique pour la protection du climat or l' "
#  "énergie nucléaire est trop lent trop cher c' est pourquoi l' autriche ne se "
#  'contente pas de faire la promotion des énergies renouvelables mais utilisent '
#  'aussi des moyens juridiques là où il y a des distorsions de concurrence ou '
#  'du greenwashing au détriment du renouvelable mais les ong environnementales '
#  "doutent que l' autriche atteignent en l' état")
#
# ("vous êtes content a branché que le levain paul d' aujourd' hui ils ont pas "
#  'leur six leur dès le début de sa mesure en temps comme un petit fierté on se '
#  "dit que je devais leur montrer réellement que l' on était même le but contre "
#  "son camp de caceres n' altère pas l' envie toulousaine franck magris pour le "
#  'trois pour la ville rose la fin de match est difficile un but de joshua une '
#  'égalisation invalider une victoire mémorable nombreux au supporters locaux '
#  "stadium j' chez étais content bianchi pour le coach le staff on croit en eux "
#  'comme les grands noms dont ceux de leur rendre leur peut simplement on est '
#  'des compétiteurs et on a pour but de se qualifier et pourquoi pas aller '
#  "gratter cette première place l' europe ouvre aussi aux ambitions l' "
#  "australie a annoncé offrir l' asile climatiques aux citoyens de tuvalu l' "
#  "archipel est menacé par la montée des eaux et ses onze mille habitants n' "
#  "ont non nulle part où aller onze onze milles c' est notre chiffre du jour "
#  "nous croyons que le peuple de tuvalu mérite d' avoir le choix de vivre "
#  "étudié et travaillé ailleurs voilà ce que dit l' australie tuvalu serait "
#  "inhabitable d' ici quatre-vingt ans écouter un ministre de l' archipel alors "
#  'on ne va pas les écouter mais on va continuer à parler climat et reprendre '
#  'un peu espoir avec notre invité du jour bonjour nicolas hazard bonjour vous '
#  'publiez happy end chez flammarion et on a bien besoin de happy end happy en '
#  "end ce en moment euh ce vous moment nous dites que la fin du monde n' est "
#  "pas forcément pour demain qu' une france des carbonisés optimiste en deux "
#  "mille cinquante c' est possible alors que les catastrophes naturelles on en "
#  "a parlé tout au long de ce journal s' enchaînent que le pas-de-calais est "
#  "sous les eaux que le mois d' octobre deux mille vingt-trois a été le plus "
#  "chaud mois d' octobre jamais enregistré comme juin juillet et août comment "
#  "ont fait alors justement c' est c' est tout le l' objet de happy end c' est "
#  "de démontrer qu' en fait on a pas vraiment commencé la transition écologique "
#  'encore pour le moment')
#
# ('dernier la cop vingt-huit qui est la conférence sur les changements '
#  "climatiques quelle merveilleuse idée d' avoir choisi dubaï pour parler du "
#  "climat quand on connaît l' utilisation massive de la climatisation sur place "
#  "et les nuages artificiels aussi pour qu' il pleuve qui arrive rarement étant "
#  "donné que tout est construit dans un désert presque tout ça n' a aucun sens "
#  "en revanche qui est beaucoup plus intéressant c' est quand anne le hidalgo "
#  "moment paris nano s' exprime aussi aller là-bas prénom affectueux vous allez "
#  "entendre l' accent est incroyable six faux n parent le souhait redux foot "
#  "paille qui s' explique oui en la langue masser un bulletin si les dieux et "
#  "paris dirais moi en je fin dirais de soirée moi à trois heures du matin j' "
#  "essaye de m' exprimer ce qu' ils sont un peu ironique politique et moi ça m' "
#  'a semblé animations mais après on se demande pourquoi la france et la risée '
#  "du monde j' ai envie de dire on entend beaucoup le bâton comme il faut une "
#  'cérémonie française maintenant qui récompense les les hommes et les femmes '
#  "de l' année absolument hoare principalement les hommes puisque c' est "
#  'organisé par le magazine masculin gq mais ça récompense aussi les femmes ce '
#  "sont les personnalités en fait hommes et femmes qui ont marqué l' année si "
#  'vous préférez un événement au organisé shangri au la palace shangri parisien '
#  'incroyable la il y palace avait parisien du moment incroyable ne regardez '
#  'bien vous êtes sûr de ce que vous venez de dire je suis très sûr vous avez '
#  'dit il y a du bon montre du beau monde oui et vous êtes moqueurs géraldine '
#  "nakache par exemple alors oui oui qui était ici pour l' occasion bilal "
#  'hassani carmen donnée particulière la chanteuse alors la françois civil '
#  "homme de l' année aya nakamura chanteuse de l' année fary <unk> humoriste de "
#  "l' année panayotis pascot et euh grippe qui a été élu journaliste de l' "
#  'année pour son travail sur sa chaîne youtube en va de sissi')
#
# ('mécanique des prix qui fait changer les comportements des consommateurs et '
#  "des producteurs et en particulier qui permet la dynamique d' innovation sans "
#  "laquelle il n' y aura pas en particulier de décarbonation à l' inverse cette "
#  "société post capitaliste que les écolos souhaitent que vous appelez l' "
#  'idéologie collapso décroissant cistes ça je serais forcément autoritaire '
#  "pour vous mais en fait euh l' idéologie collapso décroissant six c nous "
#  "enfermer dans une dichotomie d' avenir c' est à nous dire c' est soit eux le "
#  "collapsed c' est-à-dire la l' civilisation effondrement thermo de "
#  "industrielle la c' civilisation terme est aux l' industriels horreur des "
#  "milliards de mort soit la décroissance c' est-à-dire un système qui fait "
#  "sans le marché sans l' allocation des ressources par le marché c' est très "
#  'important ça et qui donc doit planifier un système de planification '
#  'économique intégral qui aurait énormément de mal pour gérer le rationnement '
#  'la pénurie et la misère à rester démocratique et vous dites même que greta '
#  "thunberg a tué euh l' écologie et ça c' était un effet de manche dans une "
#  "dans une tribune non mes non amis non alors les non les alors chiens les j' "
#  'enchères ai un regard très ambivalent surtout ce mouvement la il est très '
#  "utile parce qu' il entretient une pression politique permanent sur les "
#  "décideurs et ça c' est très important en l' occurrence pour cette tribune la "
#  'soeur greta thunberg elle confondait son combat légitime écologiste avec les '
#  "événements d' israël palestine la guerre du hamas c' est donc je disais qu' "
#  "il fallait pas tout mettre dans le même sac que voilà diluer l' écologie "
#  "dans toutes les causes on ne peut pas faire de l' intersectionnalité woke "
#  "eux sous prétexte d' écologie de la cop vingt-huit vous a donné raison "
#  'puisque le texte souligne me semble-t-il que la finance justement est un '
#  "facteur essentiel de l' action climatique oui alors c' est une boîte de "
#  'chocolats un peu vingt-huit faut bien comprendre que chacun y trouve et ils '
#  "placent en fait euh mais à la fin euh effectivement c' est l' ensemble de "
#  "toutes les choses qui du panel de la boîte à outils et j' ai envie de dire "
#  'qui se trouvent déployés dans la cop vingt-huit qui feront cette transition '
#  "alors euh parmi eux la finance est absolument fondamental c' est-à-dire "
#  "tarir les financements de l' exploitation des énergies fossiles l' europe on "
#  'a mis en place un outil')
